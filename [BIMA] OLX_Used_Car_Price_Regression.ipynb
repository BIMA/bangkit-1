# %%
from google.colab import drive
drive.mount('/content/gdrive')
root_path = 'gdrive/My Drive/Colab Notebooks/'
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
import numpy as np 
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats
from math import isnan
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
import tensorflow as tf

from tensorflow import keras
from tensorflow import feature_column
from tensorflow.keras import layers

print(tf.__version__)
# Out:
# 2.2.0-rc2

# %%
# df = pd.read_csv(root_path + 'mobilbekas.csv')

# !wget https://raw.githubusercontent.com/bangkitjkt/bangkit-1/master/data/mobilbekas.csv
df = pd.read_csv('mobilbekas.csv')
# Out:
# --2020-04-05 15:18:39--  https://raw.githubusercontent.com/bangkitjkt/bangkit-1/master/data/mobilbekas.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2588934 (2.5M) [text/plain]
# Saving to: ‘mobilbekas.csv’
#
# mobilbekas.csv      100%[===================>]   2.47M  9.98MB/s    in 0.2s
#
# 2020-04-05 15:18:39 (9.98 MB/s) - ‘mobilbekas.csv’ saved [2588934/2588934]

# %%
df.shape
# Out:
# (14657, 16)

# %%
df.head()
# Out:
#        Harga  ...       Nama Bursa Mobil
# 0  155000792  ...                    NaN
# 1   56000000  ...                    NaN
# 2  120000000  ...                    NaN
# 3  169000000  ...                    NaN
# 4  120000000  ...  Pasar Mobil Kemayoran
#
# [5 rows x 16 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14657 entries, 0 to 14656
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Harga             14657 non-null  int64
#  1   Lokasi            14657 non-null  object
#  2   Penjual           14657 non-null  object
#  3   Merek             14657 non-null  object
#  4   Model             14657 non-null  object
#  5   Varian            13941 non-null  object
#  6   Tahun             14657 non-null  object
#  7   Jarak tempuh      14657 non-null  object
#  8   Tipe bahan bakar  14657 non-null  object
#  9   Warna             14657 non-null  object
#  10  Transmisi         14657 non-null  object
#  11  Tipe bodi         12491 non-null  object
#  12  Kapasitas mesin   12859 non-null  object
#  13  Tipe Penjual      12175 non-null  object
#  14  Sistem Penggerak  11488 non-null  object
#  15  Nama Bursa Mobil  2547 non-null   object
# dtypes: int64(1), object(15)
# memory usage: 1.8+ MB

# %%
df.isnull().sum()
# Out:
# Harga                   0
# Lokasi                  0
# Penjual                 0
# Merek                   0
# Model                   0
# Varian                716
# Tahun                   0
# Jarak tempuh            0
# Tipe bahan bakar        0
# Warna                   0
# Transmisi               0
# Tipe bodi            2166
# Kapasitas mesin      1798
# Tipe Penjual         2482
# Sistem Penggerak     3169
# Nama Bursa Mobil    12110
# dtype: int64

# %%
# Display the statistic for column 'Harga'
df.describe()
# Out:
#               Harga
# count  1.465700e+04
# mean   2.479546e+08
# std    5.613904e+08
# min    6.000000e+06
# 25%    8.000000e+07
# 50%    1.225000e+08
# 75%    2.160000e+08
# max    1.700000e+10

# %%
# display boxplot
plt.figure(figsize=(3,6))
sns.boxplot(y='Harga', data=df,showfliers=False);

# %%
# Drop outliers grouped by 'Model'

outlier_params = {}
model_set = set()
indexes = []

for item in df['Model']:
    model_set.add(item)

for model in model_set:
    model_df = df.loc[df['Model'] == model]
    param = [model_df['Harga'].mean(),
             model_df['Harga'].std() + 1]
    
    outlier_params[model] = param

for index, row in df.iterrows():
    # Calculate Z-score then group index whose value >=3
    if (np.abs((row['Harga'] - outlier_params[row['Model']][0]) / outlier_params[row['Model']][1]) >= 3):
        indexes.append(index)

print(len(indexes))
df = df.drop(index=indexes) # Remove rows with Z-score >=3

print(df.shape)
# Out:
# 105
# (14552, 16)

# %%
# Drop outliers in general
indexes = []

for index, row in df.iterrows():
    # Calculate Z-score then group index whose value >=3
    if (np.abs((row['Harga'] - df['Harga'].mean()) / df['Harga'].std()) >= 3):
        indexes.append(index)

print(len(indexes))
df = df.drop(index=indexes) # Remove rows with Z-score >=3

print(df.shape)
# Out:
# 169
# (14383, 16)

# %%
# Fill NaN values by modus of corresponding model
from scipy import stats
from math import isnan
import numpy as np

model_nan_filler = {}
model_set = set()

for item in df['Model']:
    model_set.add(item)

for model in model_set:
    model_df = df.loc[df['Model'] == model]
    filler = [stats.mode(model_df['Kapasitas mesin'])[0][0],
              stats.mode(model_df['Sistem Penggerak'])[0][0],
              stats.mode(model_df['Tipe bodi'])[0][0],
              stats.mode(model_df['Tipe Penjual'])[0][0],
              stats.mode(model_df['Varian'])[0][0]]
    
    model_nan_filler[model] = filler

for index, row in df.iterrows():
    if row['Kapasitas mesin'] == 'nan' :
        df.at[index, 'Kapasitas mesin'] = model_nan_filler[row['Model']][0]
    if row['Sistem Penggerak'] is np.nan:
        df.at[index, 'Sistem Penggerak'] = model_nan_filler[row['Model']][1]
    if row['Tipe bodi'] is np.nan:
        df.at[index, 'Tipe bodi'] = model_nan_filler[row['Model']][2]
    if row['Tipe Penjual'] is np.nan:
        df.at[index, 'Tipe Penjual'] = model_nan_filler[row['Model']][3]
    if row['Varian'] is np.nan:
        df.at[index, 'Varian'] = model_nan_filler[row['Model']][4]

df['Kapasitas mesin'] = df['Kapasitas mesin'].astype('str')

# %%
df['Harga'].isnull().sum()
# Out:
# 0

# %%
# Separate lokasi into three columns ('Kecamatan', 'Kabupaten', 'Provinsi')

location = []
for index, row in df.iterrows():
    location.append(row['Lokasi'].split(', '))

location = pd.DataFrame(location)
location = location.drop([0, 2], axis=1) # Drop columns 'Kecamatan' and 'Provinsi'
location.rename(columns={1:'Kota/Kab'}, inplace=True) # Rename a column
df = pd.concat([df, location], axis=1) # Concate with the whole dataframe

# %%
df = df.drop(['Lokasi'], axis=1) # Drop column 'Lokasi'

# %%
df['Kota/Kab'].isnull().sum()
# Out:
# 271

# %%
df['Merek'].isnull().sum()
# Out:
# 271

# %%
# Drop column 'Penjual', 'Varian', 'Tipe bodi', and 'Nama Bursa Mobil'
df = df.drop(['Penjual', 'Varian', 'Tipe bodi', 'Nama Bursa Mobil'], axis=1)

# %%
df.head()
# Out:
#          Harga    Merek  ...         Sistem Penggerak        Kota/Kab
# 0  155000792.0      BMW  ...   Rear Wheel Drive (RWD)   Semarang Kota
# 1   56000000.0  Hyundai  ...  Front Wheel Drive (FWD)      Medan Kota
# 2  120000000.0    Isuzu  ...                      4X2  Palembang Kota
# 3  169000000.0    Isuzu  ...                      4X2     Madiun Kab.
# 4  120000000.0   Proton  ...   Rear Wheel Drive (RWD)   Jakarta Pusat
#
# [5 rows x 12 columns]

# %%
# Drop rows that have any NaN values
df = df.dropna()
print(df.shape)
df.head(100)
# Out:
# (14112, 12)
#             Harga          Merek  ...         Sistem Penggerak         Kota/Kab
# 0    1.550008e+08            BMW  ...   Rear Wheel Drive (RWD)    Semarang Kota
# 1    5.600000e+07        Hyundai  ...  Front Wheel Drive (FWD)       Medan Kota
# 2    1.200000e+08          Isuzu  ...                      4X2   Palembang Kota
# 3    1.690000e+08          Isuzu  ...                      4X2      Madiun Kab.
# 4    1.200000e+08         Proton  ...   Rear Wheel Drive (RWD)    Jakarta Pusat
# ..            ...            ...  ...                      ...              ...
# 99   1.200000e+09           Fiat  ...  Front Wheel Drive (FWD)  Jakarta Selatan
# 100  8.299998e+07         Datsun  ...  Front Wheel Drive (FWD)    Jakarta Timur
# 101  2.350000e+08      Chevrolet  ...                      4X2    Makassar Kota
# 102  2.350000e+08     Mitsubishi  ...                      4X2    Jakarta Timur
# 103  9.950000e+08  Mercedes-Benz  ...   Rear Wheel Drive (RWD)       Medan Kota
#
# [100 rows x 12 columns]

# %%
# Drop rows with value other than '>' and '<' in column 'Kapasitas Mesin'
indexes = []

for index, row in df.iterrows():
    if row['Kapasitas mesin'][0] != '>' and row['Kapasitas mesin'][0] != '<':
        indexes.append(index)
        
print(indexes)
df = df.drop(indexes)
# Out:
# [2, 5, 14, 16, 19, 20, 22, 23, 27, 28, 41, 43, 50, 62, 72, 76, 77, 98, 102, 103, 107, 113, 129, 147, 149, 155, 166, 175, 182, 211, 218, 228, 234, 241, 249, 271, 276, 280, 285, 287, 288, 290, 294, 299, 310, 322, 329, 336, 359, 360, 366, 375, 377, 379, 381, 393, 394, 395, 403, 416, 427, 445, 452, 462, 467, 471, 484, 496, 511, 516, 522, 525, 531, 536, 545, 572, 574, 581, 598, 610, 616, 617, 624, 639, 641, 649, 653, 656, 657, 664, 687, 698, 704, 715, 721, 723, 730, 740, 744, 746, 747, 753, 772, 781, 792, 801, 811, 836, 842, 857, 862, 876, 877, 879, 892, 907, 926, 928, 938, 944, 953, 955, 962, 989, 997, 1008, 1009, 1017, 1022, 1031, 1032, 1047, 1066, 1074, 1075, 1076, 1089, 1090, 1099, 1100, 1107, 1117, 1124, 1128, 1131, 1137, 1142, 1166, 1186, 1191, 1193, 1201, 1215, 1234, 1237, 1238, 1255, 1284, 1285, 1296, 1322, 1323, 1324, 1325, 1341, 1351, 1360, 1368, 1377, 1392, 1400, 1404, 1411, 1413, 1425, 1430, 1440, 1444, 1447, 1448, 1453, 1454, 1468, 1475, 1483, 1501, 1533, 1535, 1536, 1548, 1550, 1563, 1568, 1595, 1604, 1613, 1621, 1622, 1629, 1638, 1654, 1660, 1664, 1696, 1726, 1741, 1745, 1758, 1768, 1789, 1796, 1801, 1803, 1805, 1817, 1821, 1825, 1836, 1840, 1851, 1863, 1865, 1876, 1882, 1893, 1918, 1921, 1934, 1935, 1956, 1984, 1989, 1996, 2007, 2012, 2017, 2030, 2043, 2052, 2062, 2066, 2074, 2100, 2111, 2117, 2142, 
 5364, 5393, 5414, 5419, 5425, 5431, 5441, 5453, 5455, 5463, 5470, 5473, 5517, 5520, 5521, 5524, 5528, 5559, 5561, 5566, 5571, 5575, 5603, 5621, 5626, 5631, 5647, 5648, 5655, 5659, 5671, 5673, 5700, 5710, 5721, 5727, 5731, 5733, 5738, 5746, 5747, 5752, 5756, 5760, 5764, 5796, 5800, 5801, 5803, 5831, 5832, 5841, 5845, 5847, 5855, 5881, 5882, 5907, 5914, 5915, 5936, 5946, 5948, 5952 ...

# %%
df.shape
# Out:
# (12419, 12)

# %%
# Turn 'Jarak tempuh' and 'Kapasitas mesin' to numerical data
for index, row in df.iterrows():
    df.at[index, 'Jarak tempuh'] = row['Jarak tempuh'].split('-')[-1].replace(' km', '').replace('<', '').replace('>', '')
    
    df.at[index, 'Kapasitas mesin'] = row['Kapasitas mesin'].split('-')[-1][1:].replace(' cc', '')

df.head()
# Out:
#          Harga          Merek  ...         Sistem Penggerak                Kota/Kab
# 0  155000792.0            BMW  ...   Rear Wheel Drive (RWD)           Semarang Kota
# 1   56000000.0        Hyundai  ...  Front Wheel Drive (FWD)              Medan Kota
# 3  169000000.0          Isuzu  ...                      4X2             Madiun Kab.
# 4  120000000.0         Proton  ...   Rear Wheel Drive (RWD)           Jakarta Pusat
# 6  420000000.0  Mercedes-Benz  ...   Rear Wheel Drive (RWD)  Tangerang Selatan Kota
#
# [5 rows x 12 columns]

# %%
# Drop rows with value 0 in columns 'Sistem Penggerak' and 'Tipe Penjual'
indexes = []

for index, row in df.iterrows():
    if row['Sistem Penggerak'] == 0 or row['Tipe Penjual'] == 0:
        indexes.append(index)
        
print(indexes)
df = df.drop(indexes)

print(df.shape)
# Out:
# [558, 2974, 3726, 3753, 6540, 7810, 8282, 9135, 9156, 10362, 11356, 11921, 12197, 12827]
# (12405, 12)

# %%
df.isnull().sum()
# Out:
# Harga               0
# Merek               0
# Model               0
# Tahun               0
# Jarak tempuh        0
# Tipe bahan bakar    0
# Warna               0
# Transmisi           0
# Kapasitas mesin     0
# Tipe Penjual        0
# Sistem Penggerak    0
# Kota/Kab            0
# dtype: int64

# %%
# !pip install -q sklearn

# %%
import tensorflow as tf

from tensorflow import feature_column
from tensorflow.keras import layers
from sklearn.model_selection import train_test_split

# %%
# Rename dataframe columns
df = df.rename(columns={"Merek": "merek", "Model": "model", "Tahun": "tahun", 
                        "Jarak tempuh": "jarak_tempuh", "Tipe bahan bakar": "tipe_bahan_bakar", 
                        "Warna": "warna", "Transmisi": "transmisi", "Harga": "harga",
                        "Kapasitas mesin": "kapasitas_mesin", "Tipe Penjual": "tipe_penjual", 
                        "Sistem Penggerak": "sistem_penggerak", "Kota/Kab": "kota"})

# %%
df.head()
# Out:
#          harga          merek  ...         sistem_penggerak                    kota
# 0  155000792.0            BMW  ...   Rear Wheel Drive (RWD)           Semarang Kota
# 1   56000000.0        Hyundai  ...  Front Wheel Drive (FWD)              Medan Kota
# 3  169000000.0          Isuzu  ...                      4X2             Madiun Kab.
# 4  120000000.0         Proton  ...   Rear Wheel Drive (RWD)           Jakarta Pusat
# 6  420000000.0  Mercedes-Benz  ...   Rear Wheel Drive (RWD)  Tangerang Selatan Kota
#
# [5 rows x 12 columns]

# %%
# Split the dataframe into train and test
train, test = train_test_split(df, test_size=0.2)
print(len(train), 'train examples')
print(len(test), 'test examples')
# Out:
# 9924 train examples
# 2481 test examples

# %%
# Scale the labels
scale_factor = 1000000
# Scale the training set's label.
train["harga"] /= scale_factor 

# Scale the test set's label
test["harga"] /= scale_factor

# Shuffle the examples
train = train.reindex(np.random.permutation(train.index))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
from sklearn.preprocessing import minmax_scale

# Scaling column 'Jarak Tempuh'
train['jarak_tempuh'] = minmax_scale(train['jarak_tempuh'])
test['jarak_tempuh'] = minmax_scale(test['jarak_tempuh'])

# Scaling column 'Kapasitas mesin'
train['kapasitas_mesin'] = minmax_scale(train['kapasitas_mesin'])
test['kapasitas_mesin'] = minmax_scale(test['kapasitas_mesin'])
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':

# %%
train.head()
# Out:
#        harga       merek  ...         sistem_penggerak                    kota
# 8420    92.0         KIA  ...    All Wheel Drive (AWD)             Bekasi Kab.
# 3800   580.0  Volkswagen  ...  Front Wheel Drive (FWD)         Jakarta Selatan
# 3773   287.5  Mitsubishi  ...                      4X2  Tangerang Selatan Kota
# 3314    50.0       Isuzu  ...   Rear Wheel Drive (RWD)             Bekasi Kota
# 13158  115.0       Honda  ...  Front Wheel Drive (FWD)          Samarinda Kota
#
# [5 rows x 12 columns]

# %%
#from sklearn.preprocessing import LabelEncoder

#le = LabelEncoder()
#train['tipe_penjual'] = le.fit_transform(train['tipe_penjual'])
#test['tipe_penjual'] = le.fit_transform(test['tipe_penjual'])

# Set 1986 as minimum value in column 'Tahun'
train['tahun'].replace('<1986', 1986, inplace=True)
test['tahun'].replace('<1986', 1986, inplace=True)

# Scaling column 'Tahun'
train['tahun'] = minmax_scale(train['tahun'])
test['tahun'] = minmax_scale(test['tahun'])
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py:6746: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._update_inplace(new_data)
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
train.columns
# Out:
# Index(['harga', 'merek', 'model', 'tahun', 'jarak_tempuh', 'tipe_bahan_bakar',
#        'warna', 'transmisi', 'kapasitas_mesin', 'tipe_penjual',
#        'sistem_penggerak', 'kota'],
#       dtype='object')

# %%
train.head()
# Out:
#        harga       merek  ...         sistem_penggerak                    kota
# 8420    92.0         KIA  ...    All Wheel Drive (AWD)             Bekasi Kab.
# 3800   580.0  Volkswagen  ...  Front Wheel Drive (FWD)         Jakarta Selatan
# 3773   287.5  Mitsubishi  ...                      4X2  Tangerang Selatan Kota
# 3314    50.0       Isuzu  ...   Rear Wheel Drive (RWD)             Bekasi Kota
# 13158  115.0       Honda  ...  Front Wheel Drive (FWD)          Samarinda Kota
#
# [5 rows x 12 columns]

# %%
# Create an empty list that will eventually hold all feature columns.
feature_columns = []

# Create a numerical feature column to represent latitude.
tahun = tf.feature_column.numeric_column("tahun")
feature_columns.append(tahun)

# Create a numerical feature column to represent jarak tempuh.
jarak_tempuh = tf.feature_column.numeric_column("jarak_tempuh")
feature_columns.append(jarak_tempuh)

# Create a numerical feature column to represent kapasitas mesin.
kapasitas_mesin = tf.feature_column.numeric_column("kapasitas_mesin")
feature_columns.append(kapasitas_mesin)

# %%
df['merek'].unique()
# Out:
# array(['BMW', 'Hyundai', 'Isuzu', 'Proton', 'Mercedes-Benz', 'KIA',
#        'Smart', 'Mitsubishi', 'Mazda', 'Chery', 'Volkswagen', 'Toyota',
#        'Peugeot', 'Lexus', 'Audi', 'Honda', 'Nissan', 'Jeep', 'Suzuki',
#        'Daihatsu', 'Citroen', 'Datsun', 'Geely', 'Dodge', 'Mini Cooper',
#        'Chevrolet', 'Jaguar', 'Fiat', 'Land Rover', 'Ford', 'Volvo',
#        'Hino', 'Porsche', 'Wuling', 'Holden', 'Klasik dan Antik',
#        'Lain-lain', 'Renault', 'Timor', 'Maserati', 'Cadillac', 'Subaru',
#        'Tata', 'Aston Martin', 'Opel', 'Chrysler', 'Infiniti',
#        'Mobil CBU', 'Foton', 'Ssang Yong', 'Daewoo',
#        'DFSK (Dongfeng Sokon)', 'Hummer'], dtype=object)

# %%
# Create a categorical feature column to represent merek.
merek = feature_column.categorical_column_with_vocabulary_list(
      'merek', df['merek'].unique())
merek_one_hot = feature_column.indicator_column(merek)
feature_columns.append(merek_one_hot)

# Create a categorical feature column to represent model.
model = feature_column.categorical_column_with_vocabulary_list(
        'model', df['model'].unique())
model_one_hot = feature_column.indicator_column(model)
feature_columns.append(model_one_hot)

# # Create a categorical feature column to represent tipe bahan bakar.
tipebahanbakar = feature_column.categorical_column_with_vocabulary_list(
                 'tipe_bahan_bakar', df['tipe_bahan_bakar'].unique())
tipebahanbakar_one_hot = feature_column.indicator_column(tipebahanbakar)
feature_columns.append(tipebahanbakar_one_hot)

# # Create a categorical feature column to represent warna.
warna = feature_column.categorical_column_with_vocabulary_list(
        'warna', df['warna'].unique())
warna_one_hot = feature_column.indicator_column(warna)
feature_columns.append(warna_one_hot)

# Create a categorical feature column to represent transmisi.
transmisi = feature_column.categorical_column_with_vocabulary_list(
            'transmisi', df['transmisi'].unique())
transmisi_one_hot = feature_column.indicator_column(transmisi)
feature_columns.append(transmisi_one_hot)

# # Create a categorical feature column to represent tipe penjual.
tipepenjual = feature_column.categorical_column_with_vocabulary_list(
              'tipe_penjual', df['tipe_penjual'].unique())
tipepenjual_one_hot = feature_column.indicator_column(tipepenjual)
feature_columns.append(tipepenjual_one_hot)

# Create a categorical feature column to represent sistem penggerak.
sistempenggerak = feature_column.categorical_column_with_vocabulary_list(
                  'sistem_penggerak', df['sistem_penggerak'].unique())
sistempenggerak_one_hot = feature_column.indicator_column(sistempenggerak)
feature_columns.append(sistempenggerak_one_hot)

# # Create a categorical feature column to represent kota/kab.
kota = feature_column.categorical_column_with_vocabulary_list(
       'kota', df['kota'].unique())
kota_one_hot = feature_column.indicator_column(kota)
feature_columns.append(kota_one_hot)

# %%
feature_columns
# Out:
# [NumericColumn(key='tahun', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  NumericColumn(key='jarak_tempuh', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  NumericColumn(key='kapasitas_mesin', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  IndicatorColumn(categorical_column=VocabularyListCategoricalColumn(key='merek', vocabulary_list=('BMW', 'Hyundai', 'Isuzu', 'Proton', 'Mercedes-Benz', 'KIA', 'Smart', 'Mitsubishi', 'Mazda', 'Chery', 'Volkswagen', 'Toyota', 'Peugeot', 'Lexus', 'Audi', 'Honda', 'Nissan', 'Jeep', 'Suzuki', 'Daihatsu', 'Citroen', 'Datsun', 'Geely', 'Dodge', 'Mini Cooper', 'Chevrolet', 'Jaguar', 'Fiat', 'Land Rover', 'Ford', 'Volvo', 'Hino', 'Porsche', 'Wuling', 'Holden', 'Klasik dan Antik', 'Lain-lain', 'Renault', 'Timor', 'Maserati', 'Cadillac', 'Subaru', 'Tata', 'Aston Martin', 'Opel', 'Chrysler', 'Infiniti', 'Mobil CBU', 'Foton', 'Ssang Yong', 'Daewoo', 'DFSK (Dongfeng Sokon)', 'Hummer'), dtype=tf.string, default_value=-1, num_oov_buckets=0)),
#  IndicatorColumn(categorical_column=VocabularyListCategoricalColumn(key='model', vocabulary_list=('Serie 3', 'Getz', 'Grand touring', 'Lain-lain', 'SLK', 'S-Class', 'Picanto', 'Fortwo', 'Pajero Sport', 'Biante', 'Caravelle', '206', 'RX', 'C-Class', 'Audi A3', 'Freed', 'E-Class', '405', 'Panther', 'Rush', 'Accent', 'Lancer Evolution', 'Soluna', 'Innova', 'Polo', 'X-Trail', 'RX-8', 'Jeep', 'CR-V', 'Jazz', 'Ertiga', 'Sigra', '8', 'Grand livina', 'BX', 'Cross', '430', 'Gran max', 'Wagon R', 'Avega', 'HR-V', 'Go+', 'Terios', 'Panda', '2', 'Sorento', 'Mini Cooper', 'Xenia', 'Serena', 'Carry', 'Xpander', 'CX-5', 'Captiva', 'XJ', 'X1', 'Abart', 'Go', 'Trax', 'Aveo', 'Teana', 'Discovery Sport', 'Spin', 'Orlando', 'Terrano', 'Rubicon', 'Triton', 'Rio', '120', 'Astina', 'Ranger', 'APV', 'V70', '306', 'Fiesta', 'Everest', 'Vantrend', 'Corolla', 'Brio', 'XC90', 'Elf Minibus', 'New QQ', 'Escudo', 'Cakra', 'Mobilio', 'Cayenne', 'Confero S', 'Colt', 'Serie 5', 'Agya', 'Verna', 'Carry Pick-up', 'Carens II', 'Ecosport', 'CJ7', 'Colt 77 PS', 'A-Class', 'Serie 4', 'Boxster', 'H-1', 'Kijang', 'Grand Cherokee', 'Fortuner', 'Range Rover Evoque', 'S90', 'Mirage', 'Santa Fe', 'Exora', 'Audi A8', 'Klasik dan Antik', 'SX4', 'Gran max Pick-up', '406', 'GLA-Class', 'Strada Triton', 'Gemini', 'Espass', 'Splash', 'Spark', 'Lancer', 'New Tucson', 'Audi A4', 'Livina', 'Avanza', 'Starlet', 'New Panther', 'Optra', 'Excel', 'M Series', 'Ayla', 'Pajero', 'Trajet', 'Zebra', 'Sportage', 'Taruna', '6', 'Beetle', 'Megane', 'DOHC', 'Latio', 'Corolla Altis', 'Focus', 'Visto', 'Elgrand', 'Escape', 'Karimun', 'Calya', 'Safari', 'laser', 'Familia', 'Baleno next-G', 'Dutro', 'Savvy', 'QQ', 'Vios', 'Grand vitara', 'Grand Avega', 'Yaris', '307', 'Wrangler ', 'Ghibli', 'Baleno', 'CX-7', 'i10', 'CLS-Class', 'Outlander', 'CLA-Class', 'D-Max', 'L300', 'Taft', 'Odyssey', 'X5', 'March', 'Serie 7', 'Gen2', 'Juke', 'Katana', 'Voxy', 'Golf', 'Blazer', 'Escalade', 'Jimny', 'LX', 'Sienta', 'CX-3', 'Scirocco', 'Estate', 'Travello', 'E2000', 'City', 'Ignis', 'Camry', 'Delica', 'Alphard', 'Eterna', 'Kuda', 'X6', 'Carnival', 'Feroza', 'Colorado', 'i20', '5', '323', 'S515i', 'ML-Class', 'Lainnya', 'Trooper', 'XV', 'Tiguan', 'MPV', 'Swift', 'Accord', 'GLE-Class', 'MK', 'Vellfire', 'X3', '911', 'Lynx', 'Matrix', 'Cherokee', 'Xenon', 'Rio 5 Door', 'Etios Valco', 'Charade', 'T120SS', 'Evalia', 'CX-9', 'E-Pace', 'Kalos', 'Karimun estillo', 'Super Ace', 'Elantra', 'Audi A5', 'DB11', 'BR-V', 'Galant', 'Navara', '3', 'S60', 'Atoz', 'Journey', 'S-Type', 'Pregio', 'Audi Q3', 'Kijang Pick-Up', 'Serie 6', 'Touareg', 'Grandis', '500', 'Kwid', 'LS', 'i8', 'Renegade', 'Panda Cross', 'Trailblazer', 'Civic', 'Range Rover Sport', 'B-Class', 'Cortez', 'Premier', 'Willys', 'HIJET', '960', 'Clio', 'S80', 'Luxio', 'Q', 'MK 2', 'Pride', 'BT-50', '626', 'Sirion', 'Mobil CBU Lainnya', 'SOHC', 'MU-X', 'Audi A6', '300', 'Foton', 'Ferio', 'Genio', 'Sidekick', 'X-type', 'GLC-Class', 'Saga', 'Hardtop', 'Harrier', 'Lantis', 'Rexton', 'Carens I', 'Free Lander', 'Etios', 'Sahara', 'Wira', 'Carry Van', 'Vectra', 'Tiggo', 'Zafira', 'Audi Q7', 'Maestro', 'Uno', 'Aerio', 'MR-90', 'Altis', 'Optima', 'WRX STi', 'Stream', 'ES', 'Tiger', 'Forester', 'NX', 'Prestige', 'CR-Z', 'Espero', 'R-Class', 'XF', 'IS', 'Scenic', 'RAV4', 'Audi TT', 'S70', 'Range rover', 'Super Cab', 'Montera', 'Touran', 'Cayman', 'FL235 JN', 'Cruze', 'Mustang', 'GL-Class', 'CLS', 'Ace', '620', 'H-100', 'H3', 'Combi', 'Outback', 'Sonata', '408', 'Impreza', 'G-Class', 'Neo Baleno', 'Succed', 'Amenity', '207', 'Defender', 'Limo', '505', 'Tribute', '308', 'ML 350', 'QX', 'X4', 'Futura', 'Z4', 'Winner', 'MX', 'Viano', '407', 'Discovery', 'SLK-Class', 'Legacy', 'Sedona', 'L200', 'Musso', 'GS', 'SL', 'ist', 'Voltz', 'Gransport', 'M-Class', 'BRZ', 'R260', 'Shuma', 'Serie 2', 'Koleos', 'Land Cruiser', '125', 'Satria', '807', 'Audi Q5', 'Escort', 'Neo Zebra', 'Rocky', 'Esteem', 'Nav1', '3008', 'CLK', 'FX', 'LC', 'Grand escudo', 'Telstar', 'Skyline', 'Coupe', 'Kodok', 'B ...
#  IndicatorColumn(categorical_column=VocabularyListCategoricalColumn(key='tipe_bahan_bakar', vocabulary_list=('Bensin', 'Diesel', 'Hybrid', 'Listrik'), dtype=tf.string, default_value=-1, num_oov_buckets=0)),
#  IndicatorColumn(categorical_column=VocabularyListCategoricalColumn(key='warna', vocabulary_list=('Hitam', 'Biru', 'Coklat', 'Oranye', 'Silver', 'Abu-abu', 'Putih', 'Merah', 'Hijau', 'Marun', 'Ungu', 'Lainnya', 'Kuning', 'Emas'), dtype=tf.string, default_value=-1, num_oov_buckets=0)),
#  IndicatorColumn(categorical_column=VocabularyListCategoricalColumn(key='transmisi', vocabulary_list=('Automatic', 'Manual', 'Automatic Triptonic'), dtype=tf.string, default_value=-1, num_oov_buckets=0)),
#  IndicatorColumn(categorical_column=VocabularyListCategoricalColumn(key='tipe_penjual', vocabulary_list=('Individu', 'Diler'), dtype=tf.string, default_value=-1, num_oov_buckets=0)),
#  IndicatorColumn(categorical_column=VocabularyListCategoricalColumn(key='sistem_penggerak', vocabulary_list=('Rear Wheel Drive (RWD)', 'Front Wheel Drive (FWD)', '4X2', 'All Wheel Drive (AWD)', '4X4'), dtype=tf.string, default_value=-1, num_oov_buckets=0)),
#  IndicatorColumn(categorical_column=VocabularyListCategoricalColumn(key='kota', vocabulary_list=('Semarang Kota', 'Medan Kota', 'Madiun Kab.', 'Jakarta Pusat', 'Tangerang Selatan Kota', 'Jakarta Utara', 'Bekasi Kota', 'Surabaya Kota', 'Cirebon Kota', 'Kudus Kab.', 'Bandung Kota', 'Jakarta Selatan', 'Magelang Kab.', 'Tangerang Kota', 'Depok Kota', 'Payakumbuh Kota', 'Malang Kota', 'Palembang Kota', 'Bandar Lampung Kota', 'Sidoarjo  Kab.', 'Batam Kota', 'Tangerang Kab.', 'Cimahi Kota', 'Pekanbaru Kota', 'Padang Kota', 'Jakarta Timur', 'Yogyakarta Kota', 'Surakarta Kota', 'Bandung Kab.', 'Jakarta Barat', 'Gowa Kab.', 'Banjar Kab.', 'Balikpapan Kota', 'Kubu Raya Kab.', 'Makassar Kota', 'Jambi Kota', 'Boyolali Kab.', 'Bangka Selatan Kab.', 'Katingan Kab.', 'Malang Kab.', 'Banjarbaru Kota', 'Bekasi Kab.', 'Karanganyar Kab.', 'Denpasar Kota', 'Cilacap Kab.', 'Pinrang Kab.', 'Kediri Kota', 'Probolinggo Kab.', 'Bogor Kab.', 'Bogor Kota', 'Palangkaraya Kota', 'Tasikmalaya Kota', 'Samarinda Kota', 'Kab. Badung', 'Kediri  Kab.', 'Bantul Kab.', 'Kampar Kab.', 'Lima Puluh Kota Kab.', 'Banjarmasin Kota', 'Serang Kota', 'Sukoharjo Kab.', 'Banyumas Kab.', 'Mataram Kota', 'Pati Kab.', 'Pematangsiantar Kota', 'Jepara Kab.', 'Kendal Kab.', 'Brebes Kab.', 'Demak Kab.', 'Temanggung Kab.', 'Serang Kab.', 'Cirebon Kab.', 'Pontianak Kota', 'Bandung Barat Kab.', 'Tabanan Kab.', 'Sragen Kab.', 'Gianyar Kab.', 'Aceh Barat Kab.', 'Semarang Kab.', 'Sleman Kab.', 'Lamongan  Kab.', 'Tegal Kota', 'Cianjur Kab.', 'Solok Selatan Kab.', 'Kebumen Kab.', 'Pringsewu Kab.', 'Bireuen Kab.', 'Banyuwangi  Kab.', '
# %%
# Convert the list of feature columns into a layer that will later be fed into
# the model. 
my_feature_layer = tf.keras.layers.DenseFeatures(feature_columns)

# %%
train.columns
# Out:
# Index(['harga', 'merek', 'model', 'tahun', 'jarak_tempuh', 'tipe_bahan_bakar',
#        'warna', 'transmisi', 'kapasitas_mesin', 'tipe_penjual',
#        'sistem_penggerak', 'kota'],
#       dtype='object')

# %%
feature_columns
# Out:
# [NumericColumn(key='tahun', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  NumericColumn(key='jarak_tempuh', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  NumericColumn(key='kapasitas_mesin', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  IndicatorColumn(categorical_column=VocabularyListCategoricalColumn(key='merek', vocabulary_list=('BMW', 'Hyundai', 'Isuzu', 'Proton', 'Mercedes-Benz', 'KIA', 'Smart', 'Mitsubishi', 'Mazda', 'Chery', 'Volkswagen', 'Toyota', 'Peugeot', 'Lexus', 'Audi', 'Honda', 'Nissan', 'Jeep', 'Suzuki', 'Daihatsu', 'Citroen', 'Datsun', 'Geely', 'Dodge', 'Mini Cooper', 'Chevrolet', 'Jaguar', 'Fiat', 'Land Rover', 'Ford', 'Volvo', 'Hino', 'Porsche', 'Wuling', 'Holden', 'Klasik dan Antik', 'Lain-lain', 'Renault', 'Timor', 'Maserati', 'Cadillac', 'Subaru', 'Tata', 'Aston Martin', 'Opel', 'Chrysler', 'Infiniti', 'Mobil CBU', 'Foton', 'Ssang Yong', 'Daewoo', 'DFSK (Dongfeng Sokon)', 'Hummer'), dtype=tf.string, default_value=-1, num_oov_buckets=0)),
#  IndicatorColumn(categorical_column=VocabularyListCategoricalColumn(key='model', vocabulary_list=('Serie 3', 'Getz', 'Grand touring', 'Lain-lain', 'SLK', 'S-Class', 'Picanto', 'Fortwo', 'Pajero Sport', 'Biante', 'Caravelle', '206', 'RX', 'C-Class', 'Audi A3', 'Freed', 'E-Class', '405', 'Panther', 'Rush', 'Accent', 'Lancer Evolution', 'Soluna', 'Innova', 'Polo', 'X-Trail', 'RX-8', 'Jeep', 'CR-V', 'Jazz', 'Ertiga', 'Sigra', '8', 'Grand livina', 'BX', 'Cross', '430', 'Gran max', 'Wagon R', 'Avega', 'HR-V', 'Go+', 'Terios', 'Panda', '2', 'Sorento', 'Mini Cooper', 'Xenia', 'Serena', 'Carry', 'Xpander', 'CX-5', 'Captiva', 'XJ', 'X1', 'Abart', 'Go', 'Trax', 'Aveo', 'Teana', 'Discovery Sport', 'Spin', 'Orlando', 'Terrano', 'Rubicon', 'Triton', 'Rio', '120', 'Astina', 'Ranger', 'APV', 'V70', '306', 'Fiesta', 'Everest', 'Vantrend', 'Corolla', 'Brio', 'XC90', 'Elf Minibus', 'New QQ', 'Escudo', 'Cakra', 'Mobilio', 'Cayenne', 'Confero S', 'Colt', 'Serie 5', 'Agya', 'Verna', 'Carry Pick-up', 'Carens II', 'Ecosport', 'CJ7', 'Colt 77 PS', 'A-Class', 'Serie 4', 'Boxster', 'H-1', 'Kijang', 'Grand Cherokee', 'Fortuner', 'Range Rover Evoque', 'S90', 'Mirage', 'Santa Fe', 'Exora', 'Audi A8', 'Klasik dan Antik', 'SX4', 'Gran max Pick-up', '406', 'GLA-Class', 'Strada Triton', 'Gemini', 'Espass', 'Splash', 'Spark', 'Lancer', 'New Tucson', 'Audi A4', 'Livina', 'Avanza', 'Starlet', 'New Panther', 'Optra', 'Excel', 'M Series', 'Ayla', 'Pajero', 'Trajet', 'Zebra', 'Sportage', 'Taruna', '6', 'Beetle', 'Megane', 'DOHC', 'Latio', 'Corolla Altis', 'Focus', 'Visto', 'Elgrand', 'Escape', 'Karimun', 'Calya', 'Safari', 'laser', 'Familia', 'Baleno next-G', 'Dutro', 'Savvy', 'QQ', 'Vios', 'Grand vitara', 'Grand Avega', 'Yaris', '307', 'Wrangler ', 'Ghibli', 'Baleno', 'CX-7', 'i10', 'CLS-Class', 'Outlander', 'CLA-Class', 'D-Max', 'L300', 'Taft', 'Odyssey', 'X5', 'March', 'Serie 7', 'Gen2', 'Juke', 'Katana', 'Voxy', 'Golf', 'Blazer', 'Escalade', 'Jimny', 'LX', 'Sienta', 'CX-3', 'Scirocco', 'Estate', 'Travello', 'E2000', 'City', 'Ignis', 'Camry', 'Delica', 'Alphard', 'Eterna', 'Kuda', 'X6', 'Carnival', 'Feroza', 'Colorado', 'i20', '5', '323', 'S515i', 'ML-Class', 'Lainnya', 'Trooper', 'XV', 'Tiguan', 'MPV', 'Swift', 'Accord', 'GLE-Class', 'MK', 'Vellfire', 'X3', '911', 'Lynx', 'Matrix', 'Cherokee', 'Xenon', 'Rio 5 Door', 'Etios Valco', 'Charade', 'T120SS', 'Evalia', 'CX-9', 'E-Pace', 'Kalos', 'Karimun estillo', 'Super Ace', 'Elantra', 'Audi A5', 'DB11', 'BR-V', 'Galant', 'Navara', '3', 'S60', 'Atoz', 'Journey', 'S-Type', 'Pregio', 'Audi Q3', 'Kijang Pick-Up', 'Serie 6', 'Touareg', 'Grandis', '500', 'Kwid', 'LS', 'i8', 'Renegade', 'Panda Cross', 'Trailblazer', 'Civic', 'Range Rover Sport', 'B-Class', 'Cortez', 'Premier', 'Willys', 'HIJET', '960', 'Clio', 'S80', 'Luxio', 'Q', 'MK 2', 'Pride', 'BT-50', '626', 'Sirion', 'Mobil CBU Lainnya', 'SOHC', 'MU-X', 'Audi A6', '300', 'Foton', 'Ferio', 'Genio', 'Sidekick', 'X-type', 'GLC-Class', 'Saga', 'Hardtop', 'Harrier', 'Lantis', 'Rexton', 'Carens I', 'Free Lander', 'Etios', 'Sahara', 'Wira', 'Carry Van', 'Vectra', 'Tiggo', 'Zafira', 'Audi Q7', 'Maestro', 'Uno', 'Aerio', 'MR-90', 'Altis', 'Optima', 'WRX STi', 'Stream', 'ES', 'Tiger', 'Forester', 'NX', 'Prestige', 'CR-Z', 'Espero', 'R-Class', 'XF', 'IS', 'Scenic', 'RAV4', 'Audi TT', 'S70', 'Range rover', 'Super Cab', 'Montera', 'Touran', 'Cayman', 'FL235 JN', 'Cruze', 'Mustang', 'GL-Class', 'CLS', 'Ace', '620', 'H-100', 'H3', 'Combi', 'Outback', 'Sonata', '408', 'Impreza', 'G-Class', 'Neo Baleno', 'Succed', 'Amenity', '207', 'Defender', 'Limo', '505', 'Tribute', '308', 'ML 350', 'QX', 'X4', 'Futura', 'Z4', 'Winner', 'MX', 'Viano', '407', 'Discovery', 'SLK-Class', 'Legacy', 'Sedona', 'L200', 'Musso', 'GS', 'SL', 'ist', 'Voltz', 'Gransport', 'M-Class', 'BRZ', 'R260', 'Shuma', 'Serie 2', 'Koleos', 'Land Cruiser', '125', 'Satria', '807', 'Audi Q5', 'Escort', 'Neo Zebra', 'Rocky', 'Esteem', 'Nav1', '3008', 'CLK', 'FX', 'LC', 'Grand escudo', 'Telstar', 'Skyline', 'Coupe', 'Kodok', 'B ...
#  IndicatorColumn(categorical_column=VocabularyListCategoricalColumn(key='tipe_bahan_bakar', vocabulary_list=('Bensin', 'Diesel', 'Hybrid', 'Listrik'), dtype=tf.string, default_value=-1, num_oov_buckets=0)),
#  IndicatorColumn(categorical_column=VocabularyListCategoricalColumn(key='warna', vocabulary_list=('Hitam', 'Biru', 'Coklat', 'Oranye', 'Silver', 'Abu-abu', 'Putih', 'Merah', 'Hijau', 'Marun', 'Ungu', 'Lainnya', 'Kuning', 'Emas'), dtype=tf.string, default_value=-1, num_oov_buckets=0)),
#  IndicatorColumn(categorical_column=VocabularyListCategoricalColumn(key='transmisi', vocabulary_list=('Automatic', 'Manual', 'Automatic Triptonic'), dtype=tf.string, default_value=-1, num_oov_buckets=0)),
#  IndicatorColumn(categorical_column=VocabularyListCategoricalColumn(key='tipe_penjual', vocabulary_list=('Individu', 'Diler'), dtype=tf.string, default_value=-1, num_oov_buckets=0)),
#  IndicatorColumn(categorical_column=VocabularyListCategoricalColumn(key='sistem_penggerak', vocabulary_list=('Rear Wheel Drive (RWD)', 'Front Wheel Drive (FWD)', '4X2', 'All Wheel Drive (AWD)', '4X4'), dtype=tf.string, default_value=-1, num_oov_buckets=0)),
#  IndicatorColumn(categorical_column=VocabularyListCategoricalColumn(key='kota', vocabulary_list=('Semarang Kota', 'Medan Kota', 'Madiun Kab.', 'Jakarta Pusat', 'Tangerang Selatan Kota', 'Jakarta Utara', 'Bekasi Kota', 'Surabaya Kota', 'Cirebon Kota', 'Kudus Kab.', 'Bandung Kota', 'Jakarta Selatan', 'Magelang Kab.', 'Tangerang Kota', 'Depok Kota', 'Payakumbuh Kota', 'Malang Kota', 'Palembang Kota', 'Bandar Lampung Kota', 'Sidoarjo  Kab.', 'Batam Kota', 'Tangerang Kab.', 'Cimahi Kota', 'Pekanbaru Kota', 'Padang Kota', 'Jakarta Timur', 'Yogyakarta Kota', 'Surakarta Kota', 'Bandung Kab.', 'Jakarta Barat', 'Gowa Kab.', 'Banjar Kab.', 'Balikpapan Kota', 'Kubu Raya Kab.', 'Makassar Kota', 'Jambi Kota', 'Boyolali Kab.', 'Bangka Selatan Kab.', 'Katingan Kab.', 'Malang Kab.', 'Banjarbaru Kota', 'Bekasi Kab.', 'Karanganyar Kab.', 'Denpasar Kota', 'Cilacap Kab.', 'Pinrang Kab.', 'Kediri Kota', 'Probolinggo Kab.', 'Bogor Kab.', 'Bogor Kota', 'Palangka
 'Karangasem Kab.', 'Kendari Kota', 'Lombok Tengah Kab.', 'Bone Bolango Kab.', 'Bojonegoro Kab.', 'Lombok Timur Kab.', 'Sumedang Kab.', 'Langsa Kota', 'Subang Kab.', 'Labuhanbatu Kab.', 'Lampung Utara Kab.', 'Tapin  Kab.', 'Padang Lawas Kab.', 'Ogan Komering Ilir Kab.', 'Ogan Ilir Kab.', 'Blora Kab.', 'Agam Kab.', 'Bengkulu Utara Kab.', 'Batu Kota', 'Pemalang Kab.', 'Mukomuko Kab.', 'Kutai Timur Kab.', 'Banyuasin Kab.', 'Lombok Barat Kab.', 'Majalengka Kab.', 'Bondowoso Kab.', 'Aceh Tengah Kab.', 'Ciamis Kab.', 'Sanggau Kab.', 'Indragiri Hulu Kab.', 'Sijunjung Kab.', 'Karo Kab.', 'Dumai Kota', 'Kuningan Kab.', 'Tanggamus Kab.', 'Solok Kab.', 'Kepahiang Kab.', 'Kotawaringin Barat Kab.', 'Muara Enim Kab.', 'Aceh Utara Kab.', 'Pelalawan Kab.', 'Tegal Kab.', 'Rokan Hilir Kab.', 'Klungkung Kab.', 'Sinjai Kab.', 'Lahat Kab.', 'Soppeng Kab ...

# %%
# Define a deep neural net model

def create_model(my_learning_rate, my_feature_layer):
  """Create and compile a simple linear regression model."""
  # Most simple tf.keras models are sequential.
  model = tf.keras.models.Sequential()

  # Add the layer containing the feature columns to the model.
  model.add(my_feature_layer)

  # Describe the topography of the model by calling the tf.keras.layers.Dense
  # method once for each layer. We've specified the following arguments:
  #   * units specifies the number of nodes in this layer.
  #   * activation specifies the activation function (Rectified Linear Unit).
  #   * name is just a string that can be useful when debugging.

  # Define the first hidden layer with 20 nodes.   
  model.add(tf.keras.layers.Dense(units=120, 
                                  activation='relu', 
                                  name='Hidden1'))
  
  # Define the second hidden layer with 12 nodes. 
  model.add(tf.keras.layers.Dense(units=100, 
                                  activation='relu', 
                                  name='Hidden2'))
  
  # Define the output layer.
  model.add(tf.keras.layers.Dense(units=1,  
                                  name='Output'))                              
  
  model.compile(optimizer=tf.keras.optimizers.Adam(lr=my_learning_rate),
                loss="mean_squared_error",
                metrics=[tf.keras.metrics.MeanSquaredError()])

  return model

# %%
# Define a training function

def train_model(model, dataset, epochs, label_name,
                batch_size=None):
  """Train the model by feeding it data."""

  # Split the dataset into features and label.
  features = {name:np.array(value) for name, value in dataset.items()}
  label = np.array(features.pop(label_name))
  history = model.fit(x=features, y=label, batch_size=batch_size,
                      epochs=epochs, shuffle=True, verbose=2) 

  # The list of epochs is stored separately from the rest of history.
  epochs = history.epoch
  
  # To track the progression of training, gather a snapshot
  # of the model's mean squared error at each epoch. 
  hist = pd.DataFrame(history.history)
  mse = hist["mean_squared_error"]

  return epochs, mse

# %%
# Define the plotting function.

def plot_the_loss_curve(epochs, mse):
  """Plot a curve of loss vs. epoch."""

  plt.figure()
  plt.xlabel("Epoch")
  plt.ylabel("Mean Squared Error")

  plt.plot(epochs, mse, label="Loss")
  plt.legend()
  plt.ylim([mse.min()*0.95, mse.max() * 1.03])
  plt.show()  

print("Defined the plot_the_loss_curve function.")
# Out:
# Defined the plot_the_loss_curve function.

# %%
train.head()
# Out:
#        harga       merek  ...         sistem_penggerak                    kota
# 8420    92.0         KIA  ...    All Wheel Drive (AWD)             Bekasi Kab.
# 3800   580.0  Volkswagen  ...  Front Wheel Drive (FWD)         Jakarta Selatan
# 3773   287.5  Mitsubishi  ...                      4X2  Tangerang Selatan Kota
# 3314    50.0       Isuzu  ...   Rear Wheel Drive (RWD)             Bekasi Kota
# 13158  115.0       Honda  ...  Front Wheel Drive (FWD)          Samarinda Kota
#
# [5 rows x 12 columns]

# %%
# Call the functions to build and train a deep neural net

# The following variables are the hyperparameters.
learning_rate = 0.01
epochs = 10000
batch_size = 1024

# Specify the label
label_name = "harga"

# Establish the model's topography.
my_model = create_model(learning_rate, my_feature_layer)

# Train the model on the normalized training set. We're passing the entire
# normalized training set, but the model will only use the features
# defined by the feature_layer.
epochs, mse = train_model(my_model, train, epochs, 
                          label_name, batch_size)
plot_the_loss_curve(epochs, mse)

# After building a model against the training set, test that model
# against the test set.
test_features = {name:np.array(value) for name, value in test.items()}
test_label = np.array(test_features.pop(label_name)) # isolate the label
print("\n Evaluate the new model against the test set:")
my_model.evaluate(x = test_features, y = test_label, batch_size=batch_size)
# Out:
# Streaming output truncated to the last 5000 lines.
# 10/10 - 0s - loss: 5.7439 - mean_squared_error: 5.8211
# Epoch 7502/10000
# 10/10 - 0s - loss: 5.8243 - mean_squared_error: 5.6867
# Epoch 7503/10000
# 10/10 - 0s - loss: 5.4981 - mean_squared_error: 5.5621
# Epoch 7504/10000
# 10/10 - 0s - loss: 5.8185 - mean_squared_error: 5.6180
# Epoch 7505/10000
# 10/10 - 0s - loss: 5.5223 - mean_squared_error: 5.5855
# Epoch 7506/10000
# 10/10 - 0s - loss: 5.3911 - mean_squared_error: 5.4625
# Epoch 7507/10000
# 10/10 - 0s - loss: 5.3532 - mean_squared_error: 5.0754
# Epoch 7508/10000
# 10/10 - 0s - loss: 5.6662 - mean_squared_error: 5.7621
# Epoch 7509/10000
# 10/10 - 0s - loss: 5.7089 - mean_squared_error: 5.7867
# Epoch 7510/10000
# 10/10 - 0s - loss: 5.9422 - mean_squared_error: 5.8306
# Epoch 7511/10000
# 10/10 - 0s - loss: 7.2401 - mean_squared_error: 7.1492
# Epoch 7512/10000
# 10/10 - 0s - loss: 7.5262 - mean_squared_error: 7.4717
# Epoch 7513/10000
# 10/10 - 0s - loss: 6.9811 - mean_squared_error: 6.9737
# Epoch 7514/10000
# 10/10 - 0s - loss: 6.7549 - mean_squared_error: 6.6614
# Epoch 7515/10000
# 10/10 - 0s - loss: 7.0591 - mean_squared_error: 7.0403
# Epoch 7516/10000
# 10/10 - 0s - loss: 6.9943 - mean_squared_error: 7.0354
# Epoch 7517/10000
# 10/10 - 0s - loss: 6.8501 - mean_squared_error: 6.9142
# Epoch 7518/10000
# 10/10 - 0s - loss: 7.3494 - mean_squared_error: 7.3404
# Epoch 7616/10000
# 10/10 - 0s - loss: 6.6374 - mean_squared_error: 6.4920
# Epoch 7617/10000
# 10/10 - 0s - loss: 5.7605 - mean_squared_error: 5.5324
# Epoch 7618/10000
# 10/10 - 0s - loss: 6.3349 - mean_squared_error: 6.1520
# Epoch 7619/10000
# 10/10 - 0s - loss: 5.8641 - mean_squared_error: 5.8130
# Epoch 7620/10000
# 10/10 - 0s - loss: 6.1951 - mean_squared_error: 6.1994
# Epoch 7621/10000
# 10/10 - 0s - loss: 5.6462 - mean_squared_error: 5.6942
# Epoch 7622/10000
# 10/10 - 0s - loss: 5.5375 - mean_squared_error: 5.5903
# Epoch 7623/10000
# 10/10 - 0s - loss: 5.8929 - mean_squared_error: 5.9425
# Epoch 7624/10000
# 10/10 - 0s - loss: 6.0312 - mean_squared_error: 6.0563
# Epoch 7625/10000
# 10/10 - 0s - loss: 5.7746 - mean_squared_error: 5.7814
# Epoch 7626/10000
# 10/10 - 0s - loss: 6.0651 - mean_squared_error: 6.0406
# Epoch 7627/10000
# 10/10 - 0s - loss: 6.4416 - mean_squared_error: 6.4273
# Epoch 7628/10000
# 10/10 - 0s - loss: 6.3653 - mean_squared_error: 6.3857
# Epoch 7629/10000
# 10/10 - 0s - loss: 6.2467 - mean_squared_error: 6.1894
# Epoch 7630/10000
# 10/10 - 0s - loss: 5.9016 - mean_squared_error: 5.8663
# Epoch 7631/10000
# 10/10 - 0s - loss: 6.3745 - mean_squared_error: 6.2744
# Epoch 7632/10000
# 10/10 - 0s - loss: 6.0684 - mean_squared_error: 6.1093
# Epoch 7633/10000
# 10/10 - 0s - loss: 5.3692 - mean_squared_error: 5.4179
# Epoch 7634/10000
# 10/10 - 0s - loss: 5.1390 - mean_squared_error: 5.1269
# Epoch 7635/10000
# 10/10 - 0s - loss: 5.1559 - mean_squared_error: 5.1914
# Epoch 7636/10000
# 10/10 - 0s - loss: 5.2989 - mean_squared_error: 5.2678
# Epoch 7637/10000
# 10/10 - 0s - loss: 5.8935 - mean_squared_error: 5.6942
# Epoch 7638/10000
# 10/10 - 0s - loss: 8.5642 - mean_squared_error: 8.5903
# Epoch 7639/10000
# 10/10 - 0s - loss: 9.9238 - mean_squared_error: 9.9661
# Epoch 7640/10000
# 10/10 - 0s - loss: 11.4937 - mean_squared_error: 11.2623
# Epoch 7641/10000
# 10/10 - 0s - loss: 15.2882 - mean_squared_error: 15.3410
# Epoch 7642/10000
# 10/10 - 0s - loss: 13.9551 - mean_squared_error: 14.0063
# Epoch 7643/10000
# 10/10 - 0s - loss: 14.2689 - mean_squared_error: 14.2055
# Epoch 7644/10000
# 10/10 - 0s - loss: 15.2113 - mean_squared_error: 15.4804
# Epoch 7645/10000
# 10/10 - 0s - loss: 13.3348 - mean_squared_error: 13.3071
# Epoch 7646/10000
# 10/10 - 0s - loss: 10.8031 - mean_squared_error: 10.9040
# Epoch 7647/10000
# 10/10 - 0s - loss: 10.0086 - mean_squared_error: 9.9820
# Epoch 7648/10000
# Epoch 7681/10000
# 10/10 - 0s - loss: 29.4132 - mean_squared_error: 29.3586
# Epoch 7682/10000
# 10/10 - 0s - loss: 31.2044 - mean_squared_error: 30.8072
# Epoch 7683/10000
# 10/10 - 0s - loss: 26.3871 - mean_squared_error: 26.3938
# Epoch 7684/10000
# 10/10 - 0s - loss: 21.3947 - mean_squared_error: 21.4550
# Epoch 7685/10000
# 10/10 - 0s - loss: 17.5385 - mean_squared_error: 17.4138
# Epoch 7686/10000
# 10/10 - 0s - loss: 18.3525 - mean_squared_error: 18.2863
# Epoch 7687/10000
# 10/10 - 0s - loss: 19.3125 - mean_squared_error: 19.4696
# Epoch 7688/10000
# 10/10 - 0s - loss: 19.8011 - mean_squared_error: 19.6697
# Epoch 7689/10000
# 10/10 - 0s - loss: 14.6847 - mean_squared_error: 14.6764
# Epoch 7690/10000
# 10/10 - 0s - loss: 10.9714 - mean_squared_error: 10.9974
# Epoch 7691/10000
# 10/10 - 0s - loss: 11.4592 - mean_squared_error: 11.4439
# Epoch 7692/10000
# 10/10 - 0s - loss: 10.5326 - mean_squared_error: 10.3945
# Epoch 7693/10000
# 10/10 - 0s - loss: 10.7450 - mean_squared_error: 10.8524
# Epoch 7694/10000
# 10/10 - 0s - loss: 8.8430 - mean_squared_error: 8.7387
# Epoch 7695/10000
# 10/10 - 0s - loss: 7.8404 - mean_squared_error: 7.8196
# Epoch 7696/10000
# 10/10 - 0s - loss: 6.4303 - mean_squared_error: 6.4817
# Epoch 7697/10000
# 10/10 - 0s - loss: 5.9224 - mean_squared_error: 5.9666
# Epoch 7698/10000
# 10/10 - 0s - loss: 5.3447 - mean_squared_error: 5.2087
# Epoch 7699/10000
# 10/10 - 0s - loss: 5.3610 - mean_squared_error: 5.0837
# Epoch 7700/10000
# 10/10 - 0s - loss: 4.8425 - mean_squared_error: 4.8880
# Epoch 7701/10000
# 10/10 - 0s - loss: 4.6808 - mean_squared_error: 4.6999
# Epoch 7702/10000
# 10/10 - 0s - loss: 4.6318 - mean_squared_error: 4.7023
# Epoch 7703/10000
# 10/10 - 0s - loss: 4.4676 - mean_squared_error: 4.4716
# Epoch 7704/10000
# 10/10 - 0s - loss: 4.0496 - mean_squared_error: 4.1115
# Epoch 7705/10000
# 10/10 - 0s - loss: 4.2400 - mean_squared_error: 4.2585
# Epoch 7706/10000
# 10/10 - 0s - loss: 4.1639 - mean_squared_error: 4.1815
# Epoch 7707/10000
# 10/10 - 0s - loss: 4.6031 - mean_squared_error: 4.6461
# Epoch 7708/10000
# 10/10 - 0s - loss: 5.0119 - mean_squared_error: 5.0343
# Epoch 7709/10000
# 10/10 - 0s - loss: 5.9567 - mean_squared_error: 5.9911
# Epoch 7710/10000
# 10/10 - 0s - loss: 5.5663 - mean_squared_error: 5.5767
# Epoch 7711/10000
# 10/10 - 0s - loss: 7.6049 - mean_squared_error: 7.3228
# Epoch 7712/10000
# 10/10 - 0s - loss: 8.4998 - mean_squared_error: 8.6113
# Epoch 7713/10000
# 10/10 - 0s - loss: 6.9992 - mean_squared_error: 7.0159
# Epoch 7714/10000
# 10/10 - 0s - loss: 8.2277 - mean_squared_error: 8.1120
# Epoch 7715/10000
# 10/10 - 0s - loss: 8.0252 - mean_squared_error: 7.8963
# Epoch 7716/10000
# 10/10 - 0s - loss: 6.6276 - mean_squared_error: 6.6645
# Epoch 7717/10000
# 10/10 - 0s - loss: 6.4792 - mean_squared_error: 6.5556
# Epoch 7718/10000
# 10/10 - 0s - loss: 5.7466 - mean_squared_error: 5.7426
# Epoch 7719/10000
# 10/10 - 0s - loss: 5.4048 - mean_squared_error: 5.4500
# Epoch 7720/10000
# 10/10 - 0s - loss: 5.3731 - mean_squared_error: 5.2914
# Epoch 7721/10000
# 10/10 - 0s - loss: 5.2412 - mean_squared_error: 5.2548
# Epoch 7722/10000
# 10/10 - 0s - loss: 4.9976 - mean_squared_error: 5.0488
# Epoch 7723/10000
# 10/10 - 0s - loss: 4.9224 - mean_squared_error: 4.9815
# Epoch 7724/10000
# 10/10 - 0s - loss: 4.8403 - mean_squared_error: 4.8862
# Epoch 7725/10000
# 10/10 - 0s - loss: 5.1208 - mean_squared_error: 5.0364
# Epoch 7726/10000
# 10/10 - 0s - loss: 5.2773 - mean_squared_error: 5.3037
# Epoch 7727/10000
# 10/10 - 0s - loss: 5.7319 - mean_squared_error: 5.8124
# Epoch 7728/10000
# 10/10 - 0s - loss: 5.5967 - mean_squared_error: 5.6749
# Epoch 7729/10000
# 10/10 - 0s - loss: 5.4608 - mean_squared_error: 5.1534
# Epoch 7730/10000
# 10/10 - 0s - loss: 5.4366 - mean_squared_error: 5.4881
# Epoch 7731/10000
# 10/10 - 0s - loss: 5.9314 - mean_squared_error: 5.8110
# Epoch 7732/10000
# 10/10 - 0s - loss: 6.1125 - mean_squared_error: 6.1766
# Epoch 7733/10000
# 10/10 - 0s - loss: 5.5272 - mean_squared_error: 5.5763
# Epoch 7734/10000
# 10/10 - 0s - loss: 5.1007 - mean_squared_error: 5.0997
# Epoch 7735/10000
# 10/10 - 0s - loss: 5.9026 - mean_squared_error: 5.8750
# Epoch 7736/10000
# 10/10 - 0s - loss: 5.4970 - mean_squared_error: 5.5548
# Epoch 7737/10000
# 10/10 - 0s - loss: 4.9746 - mean_squared_error: 5.0205
# Epoch 7738/10000
# 10/10 - 0s - loss: 5.4323 - mean_squared_error: 5.4593
# Epoch 7739/10000
# 10/10 - 0s - loss: 5.1467 - mean_squared_error: 5.1416
# Epoch 7740/10000
# 10/10 - 0s - loss: 5.3442 - mean_squared_error: 5.2435
# Epoch 7741/10000
# 10/10 - 0s - loss: 5.4483 - mean_squared_error: 5.5211
# Epoch 7742/10000
# 10/10 - 0s - loss: 5.7710 - mean_squared_error: 5.8595
# Epoch 7743/10000
# 10/10 - 0s - loss: 5.8743 - mean_squared_error: 5.8757
# Epoch 7744/10000
# 10/10 - 0s - loss: 8.0311 - mean_squared_error: 7.9689
# Epoch 7745/10000
# 10/10 - 0s - loss: 8.3968 - mean_squared_error: 8.4554
# Epoch 7746/10000
# 10/10 - 0s - loss: 8.9399 - mean_squared_error: 8.8745
# Epoch 7747/10000
# 10/10 - 0s - loss: 9.3584 - mean_squared_error: 9.3719
# Epoch 7748/10000
# 10/10 - 0s - loss: 8.7097 - mean_squared_error: 8.5684
# Epoch 7749/10000
# 10/10 - 0s - loss: 9.8491 - mean_squared_error: 9.9837
# Epoch 7750/10000
# 10/10 - 0s - loss: 9.9563 - mean_squared_error: 9.9662
# Epoch 7751/10000
# 10/10 - 0s - loss: 9.4807 - mean_squared_error: 9.5598
# Epoch 7752/10000
# 10/10 - 0s - loss: 8.6672 - mean_squared_error: 8.7274
# Epoch 7753/10000
# 10/10 - 0s - loss: 8.5966 - mean_squared_error: 8.6275
# Epoch 7754/10000
# 10/10 - 0s - loss: 8.5689 - mean_squared_error: 8.4709
# Epoch 7755/10000
# 10/10 - 0s - loss: 7.5928 - mean_squared_error: 7.6065
# Epoch 7756/10000
# 10/10 - 0s - loss: 6.9645 - mean_squared_error: 6.9780
# Epoch 7757/10000
# 10/10 - 0s - loss: 6.6813 - mean_squared_error: 6.7548
# Epoch 7758/10000
# 10/10 - 0s - loss: 7.0973 - mean_squared_error: 6.8769
# Epoch 7759/10000
# 10/10 - 0s - loss: 6.0436 - mean_squared_error: 6.1360
# Epoch 7760/10000
# 10/10 - 0s - loss: 6.3109 - mean_squared_error: 6.3749
# Epoch 7761/10000
# 10/10 - 0s - loss: 7.1675 - mean_squared_error: 6.7671
# Epoch 7762/10000
# 10/10 - 0s - loss: 6.4870 - mean_squared_error: 6.5379
# Epoch 7763/10000
# 10/10 - 0s - loss: 7.1282 - mean_squared_error: 7.1785
# Epoch 7764/10000
# 10/10 - 0s - loss: 7.4126 - mean_squared_error: 7.2926
# Epoch 7765/10000
# 10/10 - 0s - loss: 6.9350 - mean_squared_error: 6.9879
# Epoch 7766/10000
# 10/10 - 0s - loss: 6.7499 - mean_squared_error: 6.7885
# Epoch 7767/10000
# 10/10 - 0s - loss: 6.5167 - mean_squared_error: 6.5105
# Epoch 7768/10000
# 10/10 - 0s - loss: 6.1738 - mean_squared_error: 6.2392
# Epoch 7769/10000
# 10/10 - 0s - loss: 6.3114 - mean_squared_error: 6.3835
# Epoch 7770/10000
# 10/10 - 0s - loss: 6.2880 - mean_squared_error: 6.2919
# Epoch 7771/10000
# 10/10 - 0s - loss: 5.5815 - mean_squared_error: 5.6597
# Epoch 7772/10000
# 10/10 - 0s - loss: 5.4023 - mean_squared_error: 5.4115
# Epoch 7773/10000
# 10/10 - 0s - loss: 5.9832 - mean_squared_error: 5.9852
# Epoch 7774/10000
# 10/10 - 0s - loss: 7.3920 - mean_squared_error: 7.4616
# Epoch 7775/10000
# 10/10 - 0s - loss: 6.3756 - mean_squared_error: 6.4277
# Epoch 7776/10000
# 10/10 - 0s - loss: 6.8470 - mean_squared_error: 6.8365
# Epoch 7777/10000
# 10/10 - 0s - loss: 6.3827 - mean_squared_error: 6.2585
# Epoch 7778/10000
# 10/10 - 0s - loss: 5.6524 - mean_squared_error: 5.6906
# Epoch 7779/10000
# 10/10 - 0s - loss: 5.6822 - mean_squared_error: 5.5011
# Epoch 7780/10000
# 10/10 - 0s - loss: 5.2389 - mean_squared_error: 5.2079
# Epoch 7781/10000
# 10/10 - 0s - loss: 5.2770 - mean_squared_error: 5.3102
# Epoch 7782/10000
# 10/10 - 0s - loss: 5.5898 - mean_squared_error: 5.6548
# Epoch 7783/10000
# 10/10 - 0s - loss: 5.9114 - mean_squared_error: 5.6505
# Epoch 7784/10000
# 10/10 - 0s - loss: 5.6554 - mean_squared_error: 5.6231
# Epoch 7785/10000
# 10/10 - 0s - loss: 5.6953 - mean_squared_error: 5.6833
# Epoch 7786/10000
# 10/10 - 0s - loss: 6.6305 - mean_squared_error: 6.5646
# Epoch 7787/10000
# 10/10 - 0s - loss: 7.2995 - mean_squared_error: 7.3488
# Epoch 7788/10000
# 10/10 - 0s - loss: 7.1816 - mean_squared_error: 7.2812
# Epoch 7789/10000
# 10/10 - 0s - loss: 9.3948 - mean_squared_error: 9.5006
# Epoch 7790/10000
# 10/10 - 0s - loss: 8.8541 - mean_squared_error: 8.6225
# Epoch 7791/10000
# 10/10 - 0s - loss: 9.3367 - mean_squared_error: 9.4527
# Epoch 7792/10000
# 10/10 - 0s - loss: 8.9948 - mean_squared_error: 8.9836
# Epoch 7793/10000
# 10/10 - 0s - loss: 9.2937 - mean_squared_error: 9.3276
# Epoch 7794/10000
# 10/10 - 0s - loss: 8.1417 - mean_squared_error: 8.1755
# Epoch 7795/10000
# 10/10 - 0s - loss: 7.6913 - mean_squared_error: 7.7695
# Epoch 7796/10000
# 10/10 - 0s - loss: 6.9178 - mean_squared_error: 6.7448
# Epoch 7797/10000
# 10/10 - 0s - loss: 6.4443 - mean_squared_error: 6.5118
# Epoch 7798/10000
# 10/10 - 0s - loss: 6.2549 - mean_squared_error: 6.2486
# Epoch 7799/10000
# 10/10 - 0s - loss: 6.7971 - mean_squared_error: 6.5496
# Epoch 7800/10000
# 10/10 - 0s - loss: 7.0895 - mean_squared_error: 7.0617
# Epoch 7801/10000
# 10/10 - 0s - loss: 8.1852 - mean_squared_error: 8.1409
# Epoch 7802/10000
# 10/10 - 0s - loss: 10.1254 - mean_squared_error: 10.1823
# Epoch 7803/10000
# 10/10 - 0s - loss: 10.2247 - mean_squared_error: 10.3486
# Epoch 7804/10000
# 10/10 - 0s - loss: 9.0062 - mean_squared_error: 8.6843
# Epoch 7805/10000
# 10/10 - 0s - loss: 8.1943 - mean_squared_error: 8.2021
# Epoch 7806/10000
# 10/10 - 0s - loss: 8.3654 - mean_squared_error: 8.4380
# Epoch 7807/10000
# 10/10 - 0s - loss: 8.7405 - mean_squared_error: 8.7563
# Epoch 7808/10000
# 10/10 - 0s - loss: 8.0145 - mean_squared_error: 8.0639
# Epoch 7809/10000
# 10/10 - 0s - loss: 11.3903 - mean_squared_error: 11.5006
# Epoch 7810/10000
# 10/10 - 0s - loss: 6.4646 - mean_squared_error: 6.5484
# Epoch 7876/10000
# 10/10 - 0s - loss: 8.2536 - mean_squared_error: 8.2425
# Epoch 7877/10000
# 10/10 - 0s - loss: 7.2124 - mean_squared_error: 7.1829
# Epoch 7878/10000
# 10/10 - 0s - loss: 5.6875 - mean_squared_error: 5.7361
# Epoch 7879/10000
# 10/10 - 0s - loss: 5.6991 - mean_squared_error: 5.5243
# Epoch 7880/10000
# 10/10 - 0s - loss: 5.6647 - mean_squared_error: 5.6559
# Epoch 7881/10000
# 10/10 - 0s - loss: 5.5529 - mean_squared_error: 5.2971
# Epoch 7882/10000
# 10/10 - 0s - loss: 5.0815 - mean_squared_error: 5.1457
# Epoch 7883/10000
# 10/10 - 0s - loss: 5.0314 - mean_squared_error: 5.0761
# Epoch 7884/10000
# 10/10 - 0s - loss: 5.2805 - mean_squared_error: 5.2392
# Epoch 7885/10000
# 10/10 - 0s - loss: 4.8008 - mean_squared_error: 4.8440
# Epoch 7886/10000
# 10/10 - 0s - loss: 4.7455 - mean_squared_error: 4.8034
# Epoch 7887/10000
# 10/10 - 0s - loss: 5.0424 - mean_squared_error: 4.7861
# Epoch 7888/10000
# 10/10 - 0s - loss: 4.7304 - mean_squared_error: 4.8096
# Epoch 7889/10000
# 10/10 - 0s - loss: 5.0214 - mean_squared_error: 4.9076
# Epoch 7890/10000
# 10/10 - 0s - loss: 5.2272 - mean_squared_error: 5.2159
# Epoch 7891/10000
# 10/10 - 0s - loss: 5.5759 - mean_squared_error: 5.5649
# Epoch 7892/10000
# 10/10 - 0s - loss: 5.2995 - mean_squared_error: 5.1456
# Epoch 7893/10000
# 10/10 - 0s - loss: 4.9733 - mean_squared_error: 5.0026
# Epoch 7894/10000
# 10/10 - 0s - loss: 5.1243 - mean_squared_error: 5.1753
# Epoch 7895/10000
# 10/10 - 0s - loss: 4.8364 - mean_squared_error: 4.7643
# Epoch 7896/10000
# 10/10 - 0s - loss: 5.2702 - mean_squared_error: 5.3694
# Epoch 7897/10000
# 10/10 - 0s - loss: 5.0956 - mean_squared_error: 5.0834
# Epoch 7898/10000
# 10/10 - 0s - loss: 4.7269 - mean_squared_error: 4.7769
# Epoch 7899/10000
# 10/10 - 0s - loss: 4.8306 - mean_squared_error: 4.8647
# Epoch 7900/10000
# 10/10 - 0s - loss: 5.2057 - mean_squared_error: 5.2420
# Epoch 7901/10000
# 10/10 - 0s - loss: 5.3833 - mean_squared_error: 5.1322
# Epoch 7902/10000
# 10/10 - 0s - loss: 6.0649 - mean_squared_error: 6.0939
# Epoch 7903/10000
# 10/10 - 0s - loss: 5.8949 - mean_squared_error: 5.7393
# Epoch 7904/10000
# 10/10 - 0s - loss: 5.8071 - mean_squared_error: 5.8296
# Epoch 7905/10000
# 10/10 - 0s - loss: 6.3964 - mean_squared_error: 6.4266
# Epoch 7906/10000
# 10/10 - 0s - loss: 5.6492 - mean_squared_error: 5.7057
# Epoch 7907/10000
# Epoch 8005/10000
# 10/10 - 0s - loss: 4.4556 - mean_squared_error: 4.5084
# Epoch 8006/10000
# 10/10 - 0s - loss: 4.8294 - mean_squared_error: 4.8878
# Epoch 8007/10000
# 10/10 - 0s - loss: 5.5287 - mean_squared_error: 5.5562
# Epoch 8008/10000
# 10/10 - 0s - loss: 5.6782 - mean_squared_error: 5.6222
# Epoch 8009/10000
# 10/10 - 0s - loss: 6.8676 - mean_squared_error: 6.8009
# Epoch 8010/10000
# 10/10 - 0s - loss: 7.6447 - mean_squared_error: 7.7091
# Epoch 8011/10000
# 10/10 - 0s - loss: 6.9578 - mean_squared_error: 6.9686
# Epoch 8012/10000
# 10/10 - 0s - loss: 6.5891 - mean_squared_error: 6.5610
# Epoch 8013/10000
# 10/10 - 0s - loss: 6.1172 - mean_squared_error: 6.1956
# Epoch 8014/10000
# 10/10 - 0s - loss: 5.9784 - mean_squared_error: 6.0181
# Epoch 8015/10000
# 10/10 - 0s - loss: 6.0936 - mean_squared_error: 6.1465
# Epoch 8016/10000
# 10/10 - 0s - loss: 6.2634 - mean_squared_error: 6.2899
# Epoch 8017/10000
# 10/10 - 0s - loss: 5.9822 - mean_squared_error: 5.9998
# Epoch 8018/10000
# 10/10 - 0s - loss: 6.4225 - mean_squared_error: 6.4386
# Epoch 8019/10000
# 10/10 - 0s - loss: 5.9939 - mean_squared_error: 5.9688
# Epoch 8020/10000
# 10/10 - 0s - loss: 7.4624 - mean_squared_error: 7.4776
# Epoch 8021/10000
# 10/10 - 0s - loss: 8.5254 - mean_squared_error: 8.4877
# Epoch 8022/10000
# 10/10 - 0s - loss: 9.7674 - mean_squared_error: 9.8625
# Epoch 8023/10000
# 10/10 - 0s - loss: 10.0018 - mean_squared_error: 10.1084
# Epoch 8024/10000
# 10/10 - 0s - loss: 8.8474 - mean_squared_error: 8.8412
# Epoch 8025/10000
# 10/10 - 0s - loss: 8.5428 - mean_squared_error: 8.5927
# Epoch 8026/10000
# 10/10 - 0s - loss: 9.5975 - mean_squared_error: 9.6168
# Epoch 8027/10000
# 10/10 - 0s - loss: 14.2057 - mean_squared_error: 14.1126
# Epoch 8028/10000
# 10/10 - 0s - loss: 14.7570 - mean_squared_error: 14.9133
# Epoch 8029/10000
# 10/10 - 0s - loss: 13.6258 - mean_squared_error: 13.5747
# Epoch 8030/10000
# 10/10 - 0s - loss: 12.0364 - mean_squared_error: 12.1071
# Epoch 8031/10000
# 10/10 - 0s - loss: 12.9986 - mean_squared_error: 13.1053
# Epoch 8032/10000
# 10/10 - 0s - loss: 11.4791 - mean_squared_error: 11.3218
# Epoch 8033/10000
# 10/10 - 0s - loss: 10.0763 - mean_squared_error: 10.2021
# Epoch 8034/10000
# 10/10 - 0s - loss: 9.3418 - mean_squared_error: 9.4013
# Epoch 8035/10000
# 10/10 - 0s - loss: 8.4866 - mean_squared_error: 8.5578
# Epoch 8036/10000
# 10/10 - 0s - loss: 7.9701 - mean_squared_error: 7.9163
# Epoch 8037/10000
# 10/10 - 0s - loss: 6.9853 - mean_squared_error: 6.9839
# Epoch 8038/10000
# 10/10 - 0s - loss: 6.3851 - mean_squared_error: 6.3892
# Epoch 8039/10000
# 10/10 - 0s - loss: 6.2646 - mean_squared_error: 6.3453
# Epoch 8040/10000
# 10/10 - 0s - loss: 6.4982 - mean_squared_error: 6.5732
# Epoch 8041/10000
# 10/10 - 0s - loss: 7.9041 - mean_squared_error: 8.0307
# Epoch 8042/10000
# 10/10 - 0s - loss: 10.6332 - mean_squared_error: 10.6809
# Epoch 8043/10000
# 10/10 - 0s - loss: 12.2264 - mean_squared_error: 12.0323
# Epoch 8044/10000
# 10/10 - 0s - loss: 10.0784 - mean_squared_error: 10.0664
# Epoch 8045/10000
# 10/10 - 0s - loss: 11.3511 - mean_squared_error: 11.2510
# Epoch 8046/10000
# 10/10 - 0s - loss: 11.6583 - mean_squared_error: 11.6812
# Epoch 8047/10000
# 10/10 - 0s - loss: 12.8283 - mean_squared_error: 13.0010
# Epoch 8048/10000
# 10/10 - 0s - loss: 12.0108 - mean_squared_error: 12.0290
# Epoch 8049/10000
# 10/10 - 0s - loss: 11.4798 - mean_squared_error: 11.5197
# Epoch 8050/10000
# 10/10 - 0s - loss: 10.1984 - mean_squared_error: 10.2981
# Epoch 8051/10000
# 10/10 - 0s - loss: 14.4662 - mean_squared_error: 14.6655
# Epoch 8052/10000
# 10/10 - 0s - loss: 12.7061 - mean_squared_error: 12.7381
# Epoch 8053/10000
# 10/10 - 0s - loss: 13.0516 - mean_squared_error: 13.1813
# Epoch 8054/10000
# 10/10 - 0s - loss: 12.9491 - mean_squared_error: 12.9751
# Epoch 8055/10000
# 10/10 - 0s - loss: 10.9303 - mean_squared_error: 10.8923
# Epoch 8056/10000
# 10/10 - 0s - loss: 10.3868 - mean_squared_error: 10.4824
# Epoch 8057/10000
# 10/10 - 0s - loss: 9.9664 - mean_squared_error: 9.9676
# Epoch 8058/10000
# 10/10 - 0s - loss: 8.5355 - mean_squared_error: 8.3989
# Epoch 8059/10000
# 10/10 - 0s - loss: 7.7132 - mean_squared_error: 7.7125
# Epoch 8060/10000
# 10/10 - 0s - loss: 8.5173 - mean_squared_error: 8.5968
# Epoch 8061/10000
# 10/10 - 0s - loss: 7.9456 - mean_squared_error: 7.9991
# Epoch 8062/10000
# 10/10 - 0s - loss: 9.2832 - mean_squared_error: 9.1112
# Epoch 8063/10000
# 10/10 - 0s - loss: 7.8910 - mean_squared_error: 7.9147
# Epoch 8064/10000
# 10/10 - 0s - loss: 6.9520 - mean_squared_error: 7.0142
# Epoch 8065/10000
# 10/10 - 0s - loss: 6.4163 - mean_squared_error: 6.3298
# Epoch 8066/10000
# 10/10 - 0s - loss: 6.2982 - mean_squared_error: 6.3533
# Epoch 8067/10000
# 10/10 - 0s - loss: 5.0717 - mean_squared_error: 5.1251
# Epoch 8068/10000
# 10/10 - 0s - loss: 4.8077 - mean_squared_error: 4.8166
# Epoch 8069/10000
# 10/10 - 0s - loss: 4.7914 - mean_squared_error: 4.7935
# Epoch 8070/10000
# 10/10 - 0s - loss: 5.0318 - mean_squared_error: 5.0152
# Epoch 8071/10000
# 10/10 - 0s - loss: 5.1250 - mean_squared_error: 4.9840
# Epoch 8072/10000
# 10/10 - 0s - loss: 5.5896 - mean_squared_error: 5.6155
# Epoch 8073/10000
# 10/10 - 0s - loss: 5.1649 - mean_squared_error: 5.1967
# Epoch 8074/10000
# 10/10 - 0s - loss: 4.9911 - mean_squared_error: 4.9966
# Epoch 8075/10000
# 10/10 - 0s - loss: 5.2576 - mean_squared_error: 5.2718
# Epoch 8076/10000
# 10/10 - 0s - loss: 5.0015 - mean_squared_error: 4.8986
# Epoch 8077/10000
# 10/10 - 0s - loss: 4.8058 - mean_squared_error: 4.8377
# Epoch 8078/10000
# 10/10 - 0s - loss: 5.0831 - mean_squared_error: 5.1419
# Epoch 8079/10000
# 10/10 - 0s - loss: 5.5011 - mean_squared_error: 5.3235
# Epoch 8080/10000
# 10/10 - 0s - loss: 5.9120 - mean_squared_error: 5.9289
# Epoch 8081/10000
# 10/10 - 0s - loss: 5.9391 - mean_squared_error: 6.0118
# Epoch 8082/10000
# 10/10 - 0s - loss: 6.6320 - mean_squared_error: 6.6538
# Epoch 8083/10000
# 10/10 - 0s - loss: 6.7082 - mean_squared_error: 6.6365
# Epoch 8084/10000
# 10/10 - 0s - loss: 7.0442 - mean_squared_error: 7.1019
# Epoch 8085/10000
# 10/10 - 0s - loss: 6.0212 - mean_squared_error: 5.8902
# Epoch 8086/10000
# 10/10 - 0s - loss: 5.6395 - mean_squared_error: 5.7040
# Epoch 8087/10000
# 10/10 - 0s - loss: 5.6750 - mean_squared_error: 5.7163
# Epoch 8088/10000
# 10/10 - 0s - loss: 5.9304 - mean_squared_error: 5.8550
# Epoch 8089/10000
# 10/10 - 0s - loss: 6.3650 - mean_squared_error: 6.3245
# Epoch 8090/10000
# 10/10 - 0s - loss: 7.1240 - mean_squared_error: 6.9401
# Epoch 8091/10000
# 10/10 - 0s - loss: 8.4002 - mean_squared_error: 8.4568
# Epoch 8092/10000
# 10/10 - 0s - loss: 8.5616 - mean_squared_error: 8.5355
# Epoch 8093/10000
# 10/10 - 0s - loss: 7.4566 - mean_squared_error: 7.4312
# Epoch 8094/10000
# 10/10 - 0s - loss: 7.9858 - mean_squared_error: 7.7707
# Epoch 8095/10000
# 10/10 - 0s - loss: 8.0539 - mean_squared_error: 8.0981
# Epoch 8096/10000
# 10/10 - 0s - loss: 9.5250 - mean_squared_error: 9.2071
# Epoch 8097/10000
# 10/10 - 0s - loss: 11.3905 - mean_squared_error: 11.3800
# Epoch 8098/10000
# 10/10 - 0s - loss: 11.6497 - mean_squared_error: 11.6554
# Epoch 8099/10000
# 10/10 - 0s - loss: 10.3261 - mean_squared_error: 10.2745
# Epoch 8100/10000
# 10/10 - 0s - loss: 12.7871 - mean_squared_error: 12.8250
# Epoch 8101/10000
# 10/10 - 0s - loss: 12.3916 - mean_squared_error: 12.4269
# Epoch 8102/10000
# 10/10 - 0s - loss: 15.4063 - mean_squared_error: 15.3349
# Epoch 8103/10000
# 10/10 - 0s - loss: 12.8990 - mean_squared_error: 13.0238
# Epoch 8104/10000
# 10/10 - 0s - loss: 10.8605 - mean_squared_error: 10.8268
# Epoch 8105/10000
# 10/10 - 0s - loss: 10.4142 - mean_squared_error: 10.4550
# Epoch 8106/10000
# 10/10 - 0s - loss: 10.2123 - mean_squared_error: 10.1861
# Epoch 8107/10000
# 10/10 - 0s - loss: 9.8670 - mean_squared_error: 9.8037
# Epoch 8108/10000
# 10/10 - 0s - loss: 9.0359 - mean_squared_error: 9.1498
# Epoch 8109/10000
# 10/10 - 0s - loss: 8.0025 - mean_squared_error: 7.8858
# Epoch 8110/10000
# 10/10 - 0s - loss: 7.4631 - mean_squared_error: 7.5739
# Epoch 8111/10000
# 10/10 - 0s - loss: 6.9815 - mean_squared_error: 7.0671
# Epoch 8112/10000
# 10/10 - 0s - loss: 6.5941 - mean_squared_error: 6.6935
# Epoch 8113/10000
# 10/10 - 0s - loss: 5.9495 - mean_squared_error: 5.9272
# Epoch 8114/10000
# 10/10 - 0s - loss: 5.1775 - mean_squared_error: 5.2203
# Epoch 8115/10000
# 10/10 - 0s - loss: 6.0328 - mean_squared_error: 6.0458
# Epoch 8116/10000
# 10/10 - 0s - loss: 6.7579 - mean_squared_error: 6.7631
# Epoch 8117/10000
# 10/10 - 0s - loss: 7.4408 - mean_squared_error: 7.4160
# Epoch 8118/10000
# 10/10 - 0s - loss: 6.8368 - mean_squared_error: 6.8703
# Epoch 8119/10000
# 10/10 - 0s - loss: 7.7345 - mean_squared_error: 7.6390
# Epoch 8120/10000
# 10/10 - 0s - loss: 7.1387 - mean_squared_error: 7.1701
# Epoch 8121/10000
# 10/10 - 0s - loss: 6.8941 - mean_squared_error: 6.9439
# Epoch 8122/10000
# 10/10 - 0s - loss: 7.3805 - mean_squared_error: 6.9277
# Epoch 8123/10000
# 10/10 - 0s - loss: 7.0008 - mean_squared_error: 6.9948
# Epoch 8124/10000
# 10/10 - 0s - loss: 7.1041 - mean_squared_error: 6.9561
# Epoch 8125/10000
# 10/10 - 0s - loss: 5.9771 - mean_squared_error: 6.0142
# Epoch 8126/10000
# 10/10 - 0s - loss: 5.3927 - mean_squared_error: 5.4391
# Epoch 8127/10000
# 10/10 - 0s - loss: 5.4630 - mean_squared_error: 5.5435
# Epoch 8128/10000
# 10/10 - 0s - loss: 5.4853 - mean_squared_error: 5.5296
# Epoch 8129/10000
# 10/10 - 0s - loss: 5.6532 - mean_squared_error: 5.5495
# Epoch 8130/10000
# 10/10 - 0s - loss: 5.9520 - mean_squared_error: 5.9805
# Epoch 8131/10000
# 10/10 - 0s - loss: 6.2780 - mean_squared_error: 6.3322
# Epoch 8132/10000
# 10/10 - 0s - loss: 6.3461 - mean_squared_error: 6.1916
# Epoch 8133/10000
# 10/10 - 0s - loss: 5.4132 - mean_squared_error: 5.4763
# Epoch 8134/10000
# 10/10 - 0s - loss: 5.5589 - mean_squared_error: 5.5707
# Epoch 8135/10000
# 10/10 - 0s - loss: 5.5604 - mean_squared_error: 5.5638
# Epoch 8136/10000
# 10/10 - 0s - loss: 5.2745 - mean_squared_error: 5.3330
# Epoch 8137/10000
# 10/10 - 0s - loss: 5.2885 - mean_squared_error: 5.2510
# Epoch 8138/10000
# 10/10 - 0s - loss: 5.2346 - mean_squared_error: 5.0711
# Epoch 8139/10000
# 10/10 - 0s - loss: 5.2086 - mean_squared_error: 5.2333
# Epoch 8140/10000
# 10/10 - 0s - loss: 5.0025 - mean_squared_error: 4.9863
# Epoch 8141/10000
# 10/10 - 0s - loss: 5.4252 - mean_squared_error: 5.3505
# Epoch 8142/10000
# 10/10 - 0s - loss: 5.1638 - mean_squared_error: 5.1977
# Epoch 8143/10000
# 10/10 - 0s - loss: 4.6445 - mean_squared_error: 4.6658
# Epoch 8144/10000
# 10/10 - 0s - loss: 5.4374 - mean_squared_error: 5.5185
# Epoch 8145/10000
# 10/10 - 0s - loss: 5.8383 - mean_squared_error: 5.9155
# Epoch 8146/10000
# 10/10 - 0s - loss: 6.5028 - mean_squared_error: 6.5309
# Epoch 8147/10000
# 10/10 - 0s - loss: 7.8157 - mean_squared_error: 7.7723
# Epoch 8148/10000
# 10/10 - 0s - loss: 8.8334 - mean_squared_error: 8.8901
# Epoch 8149/10000
# 10/10 - 0s - loss: 9.5574 - mean_squared_error: 9.6392
# Epoch 8150/10000
# 10/10 - 0s - loss: 9.0679 - mean_squared_error: 9.1146
# Epoch 8151/10000
# 10/10 - 0s - loss: 12.7034 - mean_squared_error: 12.8813
# Epoch 8152/10000
# 10/10 - 0s - loss: 16.3347 - mean_squared_error: 16.1330
# Epoch 8153/10000
# 10/10 - 0s - loss: 13.6154 - mean_squared_error: 13.5969
# Epoch 8154/10000
# 10/10 - 0s - loss: 11.2517 - mean_squared_error: 11.3247
# Epoch 8155/10000
# 10/10 - 0s - loss: 10.5123 - mean_squared_error: 10.3760
# Epoch 8156/10000
# 10/10 - 0s - loss: 10.4930 - mean_squared_error: 10.5845
# Epoch 8157/10000
# 10/10 - 0s - loss: 10.1611 - mean_squared_error: 10.1930
# Epoch 8158/10000
# 10/10 - 0s - loss: 9.7556 - mean_squared_error: 9.5655
# Epoch 8159/10000
# 10/10 - 0s - loss: 7.9312 - mean_squared_error: 7.7358
# Epoch 8160/10000
# 10/10 - 0s - loss: 7.4447 - mean_squared_error: 7.4678
# Epoch 8161/10000
# 10/10 - 0s - loss: 6.3901 - mean_squared_error: 6.3931
# Epoch 8162/10000
# 10/10 - 0s - loss: 7.4153 - mean_squared_error: 7.4714
# Epoch 8163/10000
# ...
# Epoch 9782/10000
# 10/10 - 0s - loss: 7.5115 - mean_squared_error: 7.5725
# Epoch 9783/10000
# 10/10 - 0s - loss: 6.8336 - mean_squared_error: 6.8691
# Epoch 9784/10000
# 10/10 - 0s - loss: 6.2229 - mean_squared_error: 6.2804
# Epoch 9785/10000
# 10/10 - 0s - loss: 5.5383 - mean_squared_error: 5.5237
# Epoch 9851/10000
# 10/10 - 0s - loss: 5.3680 - mean_squared_error: 5.3694
# Epoch 9852/10000
# 10/10 - 0s - loss: 5.0472 - mean_squared_error: 4.9421
# Epoch 9853/10000
# 10/10 - 0s - loss: 4.5930 - mean_squared_error: 4.6572
# Epoch 9854/10000
# 10/10 - 0s - loss: 5.4507 - mean_squared_error: 5.2632
# Epoch 9855/10000
# 10/10 - 0s - loss: 4.9350 - mean_squared_error: 4.9140
# Epoch 9856/10000
# 10/10 - 0s - loss: 5.3739 - mean_squared_error: 5.3736
# Epoch 9857/10000
# 10/10 - 0s - loss: 5.5166 - mean_squared_error: 5.5465
# Epoch 9858/10000
# 10/10 - 0s - loss: 5.4385 - mean_squared_error: 5.4770
# Epoch 9859/10000
# 10/10 - 0s - loss: 6.0511 - mean_squared_error: 5.9995
# Epoch 9860/10000
# 10/10 - 0s - loss: 7.2925 - mean_squared_error: 7.2441
# Epoch 9861/10000
# 10/10 - 0s - loss: 10.1789 - mean_squared_error: 10.0672
# Epoch 9862/10000
# 10/10 - 0s - loss: 14.1632 - mean_squared_error: 14.1388
# Epoch 9863/10000
# 10/10 - 0s - loss: 14.6037 - mean_squared_error: 14.6112
# Epoch 9864/10000
# 10/10 - 0s - loss: 18.9644 - mean_squared_error: 18.6678
# Epoch 9865/10000
# 10/10 - 0s - loss: 20.3282 - mean_squared_error: 20.2755
# Epoch 9866/10000
# 10/10 - 0s - loss: 16.1721 - mean_squared_error: 16.2275
# Epoch 9867/10000
# 10/10 - 0s - loss: 12.5286 - mean_squared_error: 12.3959
# Epoch 9868/10000
# 10/10 - 0s - loss: 10.4707 - mean_squared_error: 10.5853
# Epoch 9869/10000
# 10/10 - 0s - loss: 7.9801 - mean_squared_error: 8.0167
# Epoch 9870/10000
# 10/10 - 0s - loss: 6.8739 - mean_squared_error: 6.7048
# Epoch 9871/10000
# 10/10 - 0s - loss: 7.1728 - mean_squared_error: 7.2157
# Epoch 9872/10000
# 10/10 - 0s - loss: 7.6784 - mean_squared_error: 7.4900
# Epoch 9873/10000
# 10/10 - 0s - loss: 7.2834 - mean_squared_error: 7.2491
# Epoch 9874/10000
# 10/10 - 0s - loss: 6.0920 - mean_squared_error: 6.1311
# Epoch 9875/10000
# 10/10 - 0s - loss: 5.3782 - mean_squared_error: 5.4307
# Epoch 9876/10000
# 10/10 - 0s - loss: 5.1028 - mean_squared_error: 5.1525
# Epoch 9877/10000
# 10/10 - 0s - loss: 5.0815 - mean_squared_error: 5.0692
# Epoch 9878/10000
# 10/10 - 0s - loss: 4.9574 - mean_squared_error: 4.7460
# Epoch 9879/10000
# 10/10 - 0s - loss: 5.5223 - mean_squared_error: 5.5674
# Epoch 9880/10000
# 10/10 - 0s - loss: 6.6224 - mean_squared_error: 6.6179
# Epoch 9881/10000
# 10/10 - 0s - loss: 5.9621 - mean_squared_error: 5.9537
# Epoch 9882/10000
# Epoch 9980/10000
# 10/10 - 0s - loss: 3.9358 - mean_squared_error: 3.9619
# Epoch 9981/10000
# 10/10 - 0s - loss: 4.1685 - mean_squared_error: 4.1482
# Epoch 9982/10000
# 10/10 - 0s - loss: 4.9406 - mean_squared_error: 4.9454
# Epoch 9983/10000
# 10/10 - 0s - loss: 5.1087 - mean_squared_error: 5.0426
# Epoch 9984/10000
# 10/10 - 0s - loss: 6.2445 - mean_squared_error: 6.2098
# Epoch 9985/10000
# 10/10 - 0s - loss: 7.2268 - mean_squared_error: 7.1276
# Epoch 9986/10000
# 10/10 - 0s - loss: 7.6636 - mean_squared_error: 7.5390
# Epoch 9987/10000
# 10/10 - 0s - loss: 7.2601 - mean_squared_error: 7.2782
# Epoch 9988/10000
# 10/10 - 0s - loss: 7.7355 - mean_squared_error: 7.6569
# Epoch 9989/10000
# 10/10 - 0s - loss: 6.7247 - mean_squared_error: 6.7573
# Epoch 9990/10000
# 10/10 - 0s - loss: 6.5185 - mean_squared_error: 6.5479
# Epoch 9991/10000
# 10/10 - 0s - loss: 6.7984 - mean_squared_error: 6.8084
# Epoch 9992/10000
# 10/10 - 0s - loss: 8.4915 - mean_squared_error: 8.6329
# Epoch 9993/10000
# 10/10 - 0s - loss: 9.1527 - mean_squared_error: 9.1505
# Epoch 9994/10000
# 10/10 - 0s - loss: 8.7003 - mean_squared_error: 8.6800
# Epoch 9995/10000
# 10/10 - 0s - loss: 7.8635 - mean_squared_error: 7.8952
# Epoch 9996/10000
# 10/10 - 0s - loss: 8.1505 - mean_squared_error: 8.1488
# Epoch 9997/10000
# 10/10 - 0s - loss: 7.6845 - mean_squared_error: 7.6965
# Epoch 9998/10000
# 10/10 - 0s - loss: 6.9620 - mean_squared_error: 6.8018
# Epoch 9999/10000
# 10/10 - 0s - loss: 7.9899 - mean_squared_error: 8.0575
# Epoch 10000/10000
# 10/10 - 0s - loss: 8.5365 - mean_squared_error: 8.1953
#  Evaluate the new model against the test set:
# 3/3 [==============================] - 0s 5ms/step - loss: 8332.4336 - mean_squared_error: 8461.6201
# [8332.43359375, 8461.6201171875]

# %%
train['harga']
# Out:
# 12568     99.0
# 8220      30.0
# 5162     116.0
# 1216      84.0
# 12919    715.0
#          ...
# 10889    789.0
# 9118     140.0
# 10317     99.0
# 6656      58.5
# 3902     123.0
# Name: harga, Length: 9924, dtype: float64

# %% [markdown]
# ## Try with another setup

# %%
train.head()
# Out:
#        harga       merek  ...         sistem_penggerak           kota
# 9966   275.0  Mitsubishi  ...                      4X4    Bekasi Kota
# 5384    60.0         BMW  ...   Rear Wheel Drive (RWD)    Bekasi Kota
# 13263   60.0        Tata  ...                      4X2  Jakarta Timur
# 6905   155.0       Isuzu  ...   Rear Wheel Drive (RWD)    Bekasi Kota
# 5875   175.0       Mazda  ...  Front Wheel Drive (FWD)  Denpasar Kota
#
# [5 rows x 12 columns]

# %%
train1 = train

# %%
train1.head()
# Out:
#        harga       merek  ...         sistem_penggerak           kota
# 9966   275.0  Mitsubishi  ...                      4X4    Bekasi Kota
# 5384    60.0         BMW  ...   Rear Wheel Drive (RWD)    Bekasi Kota
# 13263   60.0        Tata  ...                      4X2  Jakarta Timur
# 6905   155.0       Isuzu  ...   Rear Wheel Drive (RWD)    Bekasi Kota
# 5875   175.0       Mazda  ...  Front Wheel Drive (FWD)  Denpasar Kota
#
# [5 rows x 12 columns]

# %%
train1 = train1.drop([x for x in list(train1.columns) if x not in ['jarak_tempuh', 'kapasitas_mesin', 'tahun', 'harga', 'merek', 'transmisi']], axis = 1)
train1.head()
# Out:
#        harga       merek     tahun  jarak_tempuh  transmisi  kapasitas_mesin
# 9966   275.0  Mitsubishi  0.757576      0.322034  Automatic             1.00
# 5384    60.0         BMW  0.030303      0.305085     Manual             0.50
# 13263   60.0        Tata  0.818182      0.338983     Manual             0.25
# 6905   155.0       Isuzu  0.727273      0.389831     Manual             1.00
# 5875   175.0       Mazda  0.878788      0.084746  Automatic             1.00

# %%
# Define a deep neural net model

def create_model(my_learning_rate, my_feature_layer):
  """Create and compile a simple linear regression model."""
  # Most simple tf.keras models are sequential.
  model = tf.keras.models.Sequential()

  # Add the layer containing the feature columns to the model.
  model.add(my_feature_layer)

  # Describe the topography of the model by calling the tf.keras.layers.Dense
  # method once for each layer. We've specified the following arguments:
  #   * units specifies the number of nodes in this layer.
  #   * activation specifies the activation function (Rectified Linear Unit).
  #   * name is just a string that can be useful when debugging.

  # Define the first hidden layer with 20 nodes.   
  model.add(tf.keras.layers.Dense(units=20, 
                                  activation='relu', 
                                  name='Hidden1'))
  
  # Define the second hidden layer with 12 nodes. 
  model.add(tf.keras.layers.Dense(units=12, 
                                  activation='relu', 
                                  name='Hidden2'))
  
  # Define the output layer.
  model.add(tf.keras.layers.Dense(units=1,  
                                  name='Output'))                              
  
  model.compile(optimizer=tf.keras.optimizers.Adam(lr=my_learning_rate),
                loss="mean_squared_error",
                metrics=[tf.keras.metrics.MeanSquaredError()])

  return model

# %%
# Call the functions to build and train a deep neural net

# The following variables are the hyperparameters.
learning_rate = 0.1
epochs = 200
batch_size = 1024

# Specify the label
label_name = "harga"

# Establish the model's topography.
my_model = create_model(learning_rate, my_feature_layer)

# Train the model on the normalized training set. We're passing the entire
# normalized training set, but the model will only use the features
# defined by the feature_layer.
epochs, mse = train_model(my_model, train, epochs, 
                          label_name, batch_size)
plot_the_loss_curve(epochs, mse)
# Out:
# Epoch 1/200
# 10/10 - 0s - loss: 44119.2188 - mean_squared_error: 44733.5078
# Epoch 2/200
# 10/10 - 0s - loss: 20575.3711 - mean_squared_error: 20820.1016
# Epoch 3/200
# 10/10 - 0s - loss: 13347.7715 - mean_squared_error: 13321.1445
# Epoch 4/200
# 10/10 - 0s - loss: 10774.1055 - mean_squared_error: 10728.1982
# Epoch 5/200
# 10/10 - 0s - loss: 8664.2363 - mean_squared_error: 8761.7900
# Epoch 6/200
# 10/10 - 0s - loss: 7439.1992 - mean_squared_error: 7468.3750
# Epoch 7/200
# Epoch 175/200
# 10/10 - 0s - loss: 241.6054 - mean_squared_error: 242.6890
# Epoch 176/200
# 10/10 - 0s - loss: 234.0791 - mean_squared_error: 234.2708
# Epoch 177/200
# 10/10 - 0s - loss: 212.6202 - mean_squared_error: 212.0649
# Epoch 178/200
# 10/10 - 0s - loss: 215.0271 - mean_squared_error: 214.4946
# Epoch 179/200
# 10/10 - 0s - loss: 224.2427 - mean_squared_error: 222.8139
# Epoch 180/200
# 10/10 - 0s - loss: 244.9904 - mean_squared_error: 246.9624
# Epoch 181/200
# 10/10 - 0s - loss: 257.0833 - mean_squared_error: 256.6184
# Epoch 182/200
# 10/10 - 0s - loss: 262.4191 - mean_squared_error: 264.0288
# Epoch 183/200
# 10/10 - 0s - loss: 362.8214 - mean_squared_error: 360.9566
# Epoch 184/200
# 10/10 - 0s - loss: 350.9023 - mean_squared_error: 354.0666
# Epoch 185/200
# 10/10 - 0s - loss: 381.9479 - mean_squared_error: 382.0020
# Epoch 186/200
# 10/10 - 0s - loss: 353.4410 - mean_squared_error: 349.6002
# Epoch 187/200
# 10/10 - 0s - loss: 300.3697 - mean_squared_error: 301.3521
# Epoch 188/200
# 10/10 - 0s - loss: 274.7542 - mean_squared_error: 273.3251
# Epoch 189/200
# 10/10 - 0s - loss: 249.6820 - mean_squared_error: 248.7521
# Epoch 190/200
# 10/10 - 0s - loss: 241.0629 - mean_squared_error: 241.6875
# Epoch 191/200
# 10/10 - 0s - loss: 241.5850 - mean_squared_error: 240.6243
# Epoch 192/200
# 10/10 - 0s - loss: 193.5602 - mean_squared_error: 192.7153
# Epoch 193/200
# 10/10 - 0s - loss: 183.9508 - mean_squared_error: 185.6529
# Epoch 194/200
# 10/10 - 0s - loss: 171.4651 - mean_squared_error: 171.0878
# Epoch 195/200
# 10/10 - 0s - loss: 177.5240 - mean_squared_error: 178.6240
# Epoch 196/200
# 10/10 - 0s - loss: 174.5319 - mean_squared_error: 173.4291
# Epoch 197/200
# 10/10 - 0s - loss: 180.5437 - mean_squared_error: 179.3910
# Epoch 198/200
# 10/10 - 0s - loss: 209.3599 - mean_squared_error: 208.4390
# Epoch 199/200
# 10/10 - 0s - loss: 196.6432 - mean_squared_error: 195.3775
# Epoch 200/200
# 10/10 - 0s - loss: 291.2452 - mean_squared_error: 290.3241

# %%
# After building a model against the training set, test that model
# against the test set.
test_features = {name:np.array(value) for name, value in test.items()}
test_label = np.array(test_features.pop(label_name)) # isolate the label
print("\n Evaluate the new model against the test set:")
my_model.evaluate(x = test_features, y = test_label, batch_size=batch_size)
# Out:
#  Evaluate the new model against the test set:
# 3/3 [==============================] - 0s 7ms/step - loss: 7263.1548 - mean_squared_error: 7404.8062
# [7263.15478515625, 7404.80615234375]

# %%
epochs = 200
epochs, mse = train_model(my_model, train, epochs, 
                          label_name, batch_size)
# After building a model against the training set, test that model
# against the test set.
test_features = {name:np.array(value) for name, value in test.items()}
test_label = np.array(test_features.pop(label_name)) # isolate the label
print("\n Evaluate the new model against the test set:")
my_model.evaluate(x = test_features, y = test_label, batch_size=batch_size)
# Out:
# Epoch 1/200
# 10/10 - 0s - loss: 193.1486 - mean_squared_error: 189.3743
# Epoch 2/200
# 10/10 - 0s - loss: 165.8081 - mean_squared_error: 166.2132
# Epoch 3/200
# 10/10 - 0s - loss: 147.7792 - mean_squared_error: 146.9421
# Epoch 4/200
# 10/10 - 0s - loss: 114.5921 - mean_squared_error: 114.4996
# Epoch 5/200
# 10/10 - 0s - loss: 110.7863 - mean_squared_error: 111.3762
# Epoch 6/200
# 10/10 - 0s - loss: 108.3987 - mean_squared_error: 109.2005
# Epoch 7/200
# 10/10 - 0s - loss: 128.0849 - mean_squared_error: 124.4435
# Epoch 8/200
# 10/10 - 0s - loss: 134.1786 - mean_squared_error: 133.9782
# Epoch 9/200
# 10/10 - 0s - loss: 108.7442 - mean_squared_error: 108.4814
# Epoch 10/200
# 10/10 - 0s - loss: 111.7280 - mean_squared_error: 109.2825
# Epoch 11/200
# 10/10 - 0s - loss: 127.8082 - mean_squared_error: 127.7037
# Epoch 12/200
# 10/10 - 0s - loss: 102.8416 - mean_squared_error: 102.1285
# Epoch 13/200
# 10/10 - 0s - loss: 108.3674 - mean_squared_error: 107.2137
# Epoch 14/200
# 10/10 - 0s - loss: 97.3234 - mean_squared_error: 97.5199
# Epoch 15/200
# 10/10 - 0s - loss: 94.4931 - mean_squared_error: 95.1899
# Epoch 16/200
# 10/10 - 0s - loss: 91.4118 - mean_squared_error: 92.0639
# Epoch 17/200
# 10/10 - 0s - loss: 105.8862 - mean_squared_error: 105.7716
# Epoch 18/200
# 10/10 - 0s - loss: 93.1103 - mean_squared_error: 93.6114
# Epoch 19/200
# 10/10 - 0s - loss: 76.5809 - mean_squared_error: 76.3183
# Epoch 20/200
# 10/10 - 0s - loss: 68.8635 - mean_squared_error: 69.0437
# Epoch 21/200
# 10/10 - 0s - loss: 65.0213 - mean_squared_error: 65.0397
# Epoch 22/200
# 10/10 - 0s - loss: 60.2105 - mean_squared_error: 60.1435
# Epoch 23/200
# 10/10 - 0s - loss: 56.8664 - mean_squared_error: 56.8834
# Epoch 24/200
# 10/10 - 0s - loss: 62.4068 - mean_squared_error: 62.2728
# Epoch 25/200
# 10/10 - 0s - loss: 65.4662 - mean_squared_error: 65.9575
# Epoch 26/200
# 10/10 - 0s - loss: 63.3474 - mean_squared_error: 63.7563
# Epoch 27/200
# 10/10 - 0s - loss: 61.5941 - mean_squared_error: 61.6437
# Epoch 28/200
# 10/10 - 0s - loss: 64.5802 - mean_squared_error: 64.8001
# Epoch 29/200
# 10/10 - 0s - loss: 77.6925 - mean_squared_error: 78.1501
# Epoch 30/200
# 10/10 - 0s - loss: 83.2910 - mean_squared_error: 83.1859
# Epoch 31/200
# 10/10 - 0s - loss: 110.7541 - mean_squared_error: 109.7171
# Epoch 32/200
# 10/10 - 0s - loss: 131.9836 - mean_squared_error: 132.4505
# Epoch 33/200
# 10/10 - 0s - loss: 109.8350 - mean_squared_error: 109.7790
